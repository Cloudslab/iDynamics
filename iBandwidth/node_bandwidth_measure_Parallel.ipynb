# %%
'''Deploy cross-node bandwidth measurement pods'''

from kubernetes import client, config

def check_pods_existence(namespace):
    core_v1 = client.CoreV1Api()
    try:
        pods = core_v1.list_namespaced_pod(namespace=namespace)
        return len(pods.items) > 0  # return True if pods exist
    except client.rest.ApiException as e:
        print(f"Exception when calling CoreV1Api->list_namespaced_pod: {e}")
        return False

def deploy_bandwidth_measurement_daemonset_if_needed():
    namespace = 'measure-nodes-bd'
    ds_name = 'bandwidth-measurement-ds'
    
    # Load Kubernetes configuration
    config.load_kube_config()
    apps_v1 = client.AppsV1Api()

    # Check if pods exist in the namespace
    pods_exist = check_pods_existence(namespace)

    # If no pods exist, deploy the DaemonSet
    if not pods_exist:
        # Define the body of the DaemonSet for `iperf3` server deployment
        ds_body = client.V1DaemonSet(
            api_version="apps/v1",
            kind="DaemonSet",
            metadata=client.V1ObjectMeta(name=ds_name),
            spec=client.V1DaemonSetSpec(
                selector=client.V1LabelSelector(
                    match_labels={"app": "bandwidth-measurement"}
                ),
                template=client.V1PodTemplateSpec(
                    metadata=client.V1ObjectMeta(labels={"app": "bandwidth-measurement"}),
                    spec=client.V1PodSpec(
                        containers=[client.V1Container(
                            name="iperf3-server",
                            image="networkstatic/iperf3",
                            args=["-s"],  # Run in server mode
                            ports=[client.V1ContainerPort(container_port=5201)]
                        )],
                        restart_policy="Always"
                    )
                )
            )
        )

        # Deploy the DaemonSet
        try:
            apps_v1.create_namespaced_daemon_set(namespace=namespace, body=ds_body)
            print(f"Deployed DaemonSet {ds_name} in namespace {namespace}")
        except client.rest.ApiException as e:
            print(f"Exception when calling AppsV1Api->create_namespaced_daemon_set: {e}")
    else:
        print("Pods already exist in the namespace. Skipping DaemonSet deployment.")

# Call the function to deploy the DaemonSet if needed
deploy_bandwidth_measurement_daemonset_if_needed()
# Out:
# Pods already exist in the namespace. Skipping DaemonSet deployment.

# %%
import re
from kubernetes import client, config, stream
import concurrent.futures
import time

# Load Kubernetes configuration
config.load_kube_config()
v1 = client.CoreV1Api()

# Function to measure bandwidth between source and target pods with retries
def measure_bandwidth_from_source_to_target(v1, namespace, source_pod, target_pod, test_duration=5, max_retries=3):
    source_pod_name = source_pod.metadata.name
    source_pod_node_name = source_pod.spec.node_name
    target_pod_ip = target_pod.status.pod_ip
    target_pod_name = target_pod.metadata.name
    target_pod_node_name = target_pod.spec.node_name
    result = (source_pod_node_name, target_pod_node_name, None)

    if source_pod_name != target_pod_name:
        exec_command = ['iperf3', '-c', target_pod_ip, '-t', str(test_duration)]
        attempts = 0

        while attempts < max_retries:
            try:
                # Run iperf3 command
                resp = stream.stream(v1.connect_get_namespaced_pod_exec,
                                     source_pod_name,
                                     namespace,
                                     command=exec_command,
                                     stderr=True,
                                     stdin=False,
                                     stdout=True,
                                     tty=False)

                # Check for "server is busy" in the output
                if "the server is busy" in resp:
                    print(f"Server is busy for connection from {source_pod_name} to {target_pod_name}. Retrying...")
                    attempts += 1
                    time.sleep(test_duration/2)  # Wait before retrying
                    continue

                # Parse the output for bandwidth
                print(f"Full output from {source_pod_name} to {target_pod_name}:\n{resp}")
                match = re.search(r'(\d+\.?\d*\s[MKG]bits/sec)', resp)
                if match:
                    bandwidth = match.group(1)
                    result = (source_pod_node_name, target_pod_node_name, bandwidth)
                    print(f"Bandwidth from {source_pod_node_name} to {target_pod_node_name}: {bandwidth}")
                else:
                    print(f"Could not extract bandwidth for connection from {source_pod_name} to {target_pod_name}.")
                    result = (source_pod_node_name, target_pod_node_name, "Parsing Error")
                break  # Exit loop on success

            except Exception as e:
                print(f"Error executing command in pod {source_pod_name}: {e}")
                result = (source_pod_node_name, target_pod_node_name, "Error")
                break

        if attempts == max_retries:
            print(f"Max retries reached for connection from {source_pod_name} to {target_pod_name}.")
            result = (source_pod_node_name, target_pod_node_name, "Server Busy Error")

    return result

def measure_bandwidth(namespace='measure-nodes-bd', max_concurrent_tasks=3, test_duration=5):
    v1 = client.CoreV1Api()
    pods = v1.list_namespaced_pod(namespace, label_selector="app=bandwidth-measurement").items
    bandwidth_results = {}

    # Use ThreadPoolExecutor for controlled concurrent execution
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_concurrent_tasks) as executor:
        futures = []
        for source_pod in pods:
            for target_pod in pods:
                if source_pod.metadata.name != target_pod.metadata.name:  # Skip self-tests
                    futures.append(executor.submit(measure_bandwidth_from_source_to_target,
                                                   v1, namespace, source_pod, target_pod, test_duration))

        # Collect the completed results
        for future in concurrent.futures.as_completed(futures):
            source_pod_node_name, target_pod_node_name, bandwidth = future.result()
            if source_pod_node_name not in bandwidth_results:
                bandwidth_results[source_pod_node_name] = {}
            bandwidth_results[source_pod_node_name][target_pod_node_name] = bandwidth

    return bandwidth_results

# Call the function to measure bandwidth after deploying the DaemonSet
namespace = 'measure-nodes-bd'
# Reduced concurrency and added retry logic
bandwidth_results = measure_bandwidth(namespace=namespace, max_concurrent_tasks=3, test_duration=10)
print(bandwidth_results)
# Out:
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.69.209 port 55104 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  83.6 MBytes   701 Mbits/sec   21    930 KBytes
# [  5]   1.00-2.00   sec  73.3 MBytes   615 Mbits/sec    4   1.17 MBytes
# [  5]   2.00-3.00   sec  70.0 MBytes   587 Mbits/sec    0   1.42 MBytes
# [  5]   3.00-4.00   sec  70.0 MBytes   587 Mbits/sec    0   1.63 MBytes
# [  5]   4.00-5.00   sec  70.0 MBytes   587 Mbits/sec    0   1.82 MBytes
# [  5]   5.00-6.00   sec  70.0 MBytes   587 Mbits/sec    0   1.99 MBytes
# [  5]   6.00-7.00   sec  71.2 MBytes   598 Mbits/sec    0   2.14 MBytes
# [  5]   7.00-8.00   sec  70.0 MBytes   587 Mbits/sec    0   2.28 MBytes
# [  5]   8.00-9.00   sec  71.2 MBytes   598 Mbits/sec    0   2.44 MBytes
# [  5]   9.00-10.00  sec  70.0 MBytes   587 Mbits/sec    0   3.02 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   719 MBytes   603 Mbits/sec   25             sender
# [  5]   0.00-10.04  sec   719 MBytes   600 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-5: 701 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.69.209 port 41210 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  67.6 MBytes   567 Mbits/sec   15    782 KBytes
# [  5]   1.00-2.00   sec  70.2 MBytes   589 Mbits/sec    3   1.08 MBytes
# [  5]   2.00-3.00   sec  70.0 MBytes   587 Mbits/sec    0   1.35 MBytes
# [  5]   3.00-4.00   sec  70.0 MBytes   587 Mbits/sec    0   1.57 MBytes
# [  5]   4.00-5.00   sec  70.0 MBytes   587 Mbits/sec    0   1.76 MBytes
# [  5]   5.00-6.00   sec  70.0 MBytes   587 Mbits/sec    1   1.92 MBytes
# [  5]   6.00-7.00   sec  71.2 MBytes   598 Mbits/sec    0   2.08 MBytes
# [  5]   7.00-8.00   sec  70.0 MBytes   587 Mbits/sec    0   2.22 MBytes
# [  5]   8.00-9.00   sec  71.2 MBytes   598 Mbits/sec    0   2.37 MBytes
# [  5]   9.00-10.00  sec  70.0 MBytes   587 Mbits/sec    0   2.49 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   700 MBytes   587 Mbits/sec   19             sender
# [  5]   0.00-10.04  sec   699 MBytes   584 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-1: 567 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.69.209 port 56868 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  64.8 MBytes   544 Mbits/sec    2    773 KBytes
# [  5]   1.00-2.00   sec  69.5 MBytes   583 Mbits/sec    0   1.09 MBytes
# [  5]   2.00-3.00   sec  70.0 MBytes   587 Mbits/sec    0   1.35 MBytes
# [  5]   3.00-4.00   sec  70.0 MBytes   587 Mbits/sec    0   1.57 MBytes
# [  5]   4.00-5.00   sec  68.8 MBytes   577 Mbits/sec    0   1.76 MBytes
# [  5]   5.00-6.00   sec  71.2 MBytes   598 Mbits/sec    0   1.93 MBytes
# [  5]   6.00-7.00   sec  71.2 MBytes   598 Mbits/sec    0   2.09 MBytes
# [  5]   7.00-8.00   sec  70.0 MBytes   587 Mbits/sec    0   2.24 MBytes
# [  5]   8.00-9.00   sec  71.2 MBytes   597 Mbits/sec    0   2.61 MBytes
# [  5]   9.00-10.00  sec  68.8 MBytes   577 Mbits/sec    0   3.05 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   696 MBytes   583 Mbits/sec    2             sender
# [  5]   0.00-10.05  sec   695 MBytes   581 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-8: 544 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.69.209 port 33232 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  70.9 MBytes   595 Mbits/sec   29    782 KBytes
# [  5]   1.00-2.00   sec  71.2 MBytes   597 Mbits/sec    1   1.09 MBytes
# [  5]   2.00-3.00   sec  70.0 MBytes   587 Mbits/sec    0   1.35 MBytes
# [  5]   3.00-4.00   sec  68.8 MBytes   577 Mbits/sec    0   1.56 MBytes
# [  5]   4.00-5.00   sec  70.0 MBytes   587 Mbits/sec    0   1.76 MBytes
# [  5]   5.00-6.00   sec  70.0 MBytes   587 Mbits/sec    0   1.93 MBytes
# [  5]   6.00-7.00   sec  68.8 MBytes   577 Mbits/sec    0   2.08 MBytes
# [  5]   7.00-8.00   sec  70.0 MBytes   587 Mbits/sec    0   2.23 MBytes
# [  5]   8.00-9.00   sec  68.8 MBytes   577 Mbits/sec    1   2.35 MBytes
# [  5]   9.00-10.00  sec  68.8 MBytes   577 Mbits/sec    0   2.49 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   697 MBytes   585 Mbits/sec   31             sender
# [  5]   0.00-10.03  sec   697 MBytes   582 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-6: 595 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.69.209 port 50030 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  65.2 MBytes   547 Mbits/sec   24    730 KBytes
# [  5]   1.00-2.00   sec  69.6 MBytes   584 Mbits/sec    0   1.07 MBytes
# [  5]   2.00-3.00   sec  68.8 MBytes   577 Mbits/sec    5   1.32 MBytes
# [  5]   3.00-4.00   sec  70.0 MBytes   587 Mbits/sec    0   1.54 MBytes
# [  5]   4.00-5.00   sec  68.8 MBytes   577 Mbits/sec    0   1.73 MBytes
# [  5]   5.00-6.00   sec  70.0 MBytes   587 Mbits/sec    0   1.90 MBytes
# [  5]   6.00-7.00   sec  68.8 MBytes   577 Mbits/sec    0   2.06 MBytes
# [  5]   7.00-8.00   sec  70.0 MBytes   587 Mbits/sec    1   2.20 MBytes
# [  5]   8.00-9.00   sec  68.8 MBytes   577 Mbits/sec    0   2.33 MBytes
# [  5]   9.00-10.00  sec  68.8 MBytes   577 Mbits/sec    1   2.45 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   688 MBytes   578 Mbits/sec   31             sender
# [  5]   0.00-10.03  sec   688 MBytes   575 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-9: 547 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.69.209 port 57572 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  82.2 MBytes   690 Mbits/sec    8    895 KBytes
# [  5]   1.00-2.00   sec  73.0 MBytes   613 Mbits/sec    0   1.20 MBytes
# [  5]   2.00-3.00   sec  70.0 MBytes   587 Mbits/sec    0   1.44 MBytes
# [  5]   3.00-4.00   sec  68.8 MBytes   577 Mbits/sec    0   1.65 MBytes
# [  5]   4.00-5.00   sec  70.0 MBytes   587 Mbits/sec    1   1.82 MBytes
# [  5]   5.00-6.00   sec  68.8 MBytes   577 Mbits/sec    0   1.99 MBytes
# [  5]   6.00-7.00   sec  70.0 MBytes   587 Mbits/sec    0   2.14 MBytes
# [  5]   7.00-8.00   sec  70.0 MBytes   587 Mbits/sec    0   2.27 MBytes
# [  5]   8.00-9.00   sec  68.8 MBytes   577 Mbits/sec    0   2.42 MBytes
# [  5]   9.00-10.00  sec  70.0 MBytes   587 Mbits/sec    0   2.54 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   712 MBytes   597 Mbits/sec    9             sender
# [  5]   0.00-10.03  sec   710 MBytes   594 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-2: 690 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.69.209 port 60806 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  88.1 MBytes   739 Mbits/sec    8    930 KBytes
# [  5]   1.00-2.00   sec  83.3 MBytes   699 Mbits/sec    1   1.24 MBytes
# [  5]   2.00-3.00   sec  85.0 MBytes   713 Mbits/sec    0   1.52 MBytes
# [  5]   3.00-4.00   sec  85.0 MBytes   713 Mbits/sec    0   1.76 MBytes
# [  5]   4.00-5.00   sec  81.2 MBytes   681 Mbits/sec    0   1.95 MBytes
# [  5]   5.00-6.00   sec  83.8 MBytes   703 Mbits/sec    0   2.14 MBytes
# [  5]   6.00-7.00   sec  83.8 MBytes   703 Mbits/sec    0   2.31 MBytes
# [  5]   7.00-8.00   sec  86.2 MBytes   723 Mbits/sec    0   2.47 MBytes
# [  5]   8.00-9.00   sec  85.0 MBytes   713 Mbits/sec    0   2.62 MBytes
# [  5]   9.00-10.00  sec  87.5 MBytes   734 Mbits/sec    0   3.04 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   849 MBytes   712 Mbits/sec    9             sender
# [  5]   0.00-10.03  sec   849 MBytes   710 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-7: 739 Mbits/sec
# Full output from bandwidth-measurement-ds-6dldb to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.69.209 port 35486 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  88.2 MBytes   740 Mbits/sec    3    912 KBytes
# [  5]   1.00-2.00   sec  83.8 MBytes   703 Mbits/sec    2   1.23 MBytes
# [  5]   2.00-3.00   sec  85.0 MBytes   713 Mbits/sec    0   1.51 MBytes
# [  5]   3.00-4.00   sec  85.0 MBytes   713 Mbits/sec    0   1.75 MBytes
# [  5]   4.00-5.00   sec  81.2 MBytes   682 Mbits/sec    0   1.95 MBytes
# [  5]   5.00-6.00   sec  83.8 MBytes   703 Mbits/sec    0   2.13 MBytes
# [  5]   6.00-7.00   sec  85.0 MBytes   713 Mbits/sec    0   2.31 MBytes
# [  5]   7.00-8.00   sec  85.0 MBytes   713 Mbits/sec    0   2.47 MBytes
# [  5]   8.00-9.00   sec  86.2 MBytes   724 Mbits/sec    0   2.62 MBytes
# [  5]   9.00-10.00  sec  87.5 MBytes   734 Mbits/sec    0   3.04 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   851 MBytes   714 Mbits/sec    5             sender
# [  5]   0.00-10.03  sec   851 MBytes   711 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-3 to k8s-worker-4: 740 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.230.44 port 54228 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  94.9 MBytes   796 Mbits/sec    3    930 KBytes
# [  5]   1.00-2.00   sec  93.1 MBytes   781 Mbits/sec    0   1.29 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   1.59 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   1.83 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   2.05 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   776 Mbits/sec    3   2.24 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   2.42 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   2.59 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   2.74 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   2.89 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   936 MBytes   785 Mbits/sec    6             sender
# [  5]   0.00-10.03  sec   935 MBytes   782 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-3: 796 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.230.44 port 59512 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  93.5 MBytes   784 Mbits/sec    8    999 KBytes
# [  5]   1.00-2.00   sec  89.8 MBytes   753 Mbits/sec    1   1.31 MBytes
# [  5]   2.00-3.00   sec  90.0 MBytes   755 Mbits/sec    0   1.59 MBytes
# [  5]   3.00-4.00   sec  88.8 MBytes   745 Mbits/sec    0   1.82 MBytes
# [  5]   4.00-5.00   sec  88.8 MBytes   744 Mbits/sec    0   2.04 MBytes
# [  5]   5.00-6.00   sec  88.8 MBytes   744 Mbits/sec    0   2.22 MBytes
# [  5]   6.00-7.00   sec  90.0 MBytes   755 Mbits/sec    0   2.40 MBytes
# [  5]   7.00-8.00   sec  91.2 MBytes   765 Mbits/sec    0   2.56 MBytes
# [  5]   8.00-9.00   sec  91.2 MBytes   765 Mbits/sec    0   2.72 MBytes
# [  5]   9.00-10.00  sec  90.0 MBytes   755 Mbits/sec    0   3.03 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   902 MBytes   757 Mbits/sec    9             sender
# [  5]   0.00-10.03  sec   901 MBytes   754 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-8: 784 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.230.44 port 47174 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  93.9 MBytes   788 Mbits/sec    9    956 KBytes
# [  5]   1.00-2.00   sec  89.4 MBytes   750 Mbits/sec    0   1.29 MBytes
# [  5]   2.00-3.00   sec  90.0 MBytes   755 Mbits/sec    0   1.58 MBytes
# [  5]   3.00-4.00   sec  90.0 MBytes   755 Mbits/sec    0   1.82 MBytes
# [  5]   4.00-5.00   sec  87.5 MBytes   734 Mbits/sec    0   2.03 MBytes
# [  5]   5.00-6.00   sec  90.0 MBytes   755 Mbits/sec    0   2.21 MBytes
# [  5]   6.00-7.00   sec  90.0 MBytes   755 Mbits/sec    0   2.39 MBytes
# [  5]   7.00-8.00   sec  91.2 MBytes   765 Mbits/sec    0   2.56 MBytes
# [  5]   8.00-9.00   sec  91.2 MBytes   765 Mbits/sec    0   2.72 MBytes
# [  5]   9.00-10.00  sec  90.0 MBytes   755 Mbits/sec    0   3.05 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   903 MBytes   758 Mbits/sec    9             sender
# [  5]   0.00-10.03  sec   903 MBytes   755 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-5: 788 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.230.44 port 56844 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  91.7 MBytes   769 Mbits/sec   12    886 KBytes
# [  5]   1.00-2.00   sec  90.2 MBytes   756 Mbits/sec    0   1.26 MBytes
# [  5]   2.00-3.00   sec  88.8 MBytes   744 Mbits/sec    1   1.53 MBytes
# [  5]   3.00-4.00   sec  90.0 MBytes   755 Mbits/sec    0   1.77 MBytes
# [  5]   4.00-5.00   sec  87.5 MBytes   734 Mbits/sec    0   1.99 MBytes
# [  5]   5.00-6.00   sec  88.8 MBytes   744 Mbits/sec    0   2.18 MBytes
# [  5]   6.00-7.00   sec  90.0 MBytes   755 Mbits/sec    0   2.36 MBytes
# [  5]   7.00-8.00   sec  91.2 MBytes   765 Mbits/sec    0   2.53 MBytes
# [  5]   8.00-9.00   sec  91.2 MBytes   765 Mbits/sec    0   2.69 MBytes
# [  5]   9.00-10.00  sec  90.0 MBytes   755 Mbits/sec    0   2.83 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   899 MBytes   754 Mbits/sec   13             sender
# [  5]   0.00-10.03  sec   899 MBytes   752 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-9: 769 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.230.44 port 34972 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.0 MBytes   797 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  91.2 MBytes   765 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  91.2 MBytes   765 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  91.2 MBytes   765 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   919 MBytes   771 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   918 MBytes   768 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-6: 797 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.230.44 port 35880 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  94.5 MBytes   793 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  91.2 MBytes   765 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  91.2 MBytes   765 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  91.2 MBytes   765 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   921 MBytes   772 Mbits/sec    0             sender
# [  5]   0.00-10.05  sec   920 MBytes   768 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-2: 793 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.230.44 port 42556 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.1 MBytes   798 Mbits/sec    7   1.12 MBytes
# [  5]   1.00-2.00   sec  91.2 MBytes   765 Mbits/sec    0   1.45 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   1.71 MBytes
# [  5]   3.00-4.00   sec  90.0 MBytes   755 Mbits/sec    0   1.94 MBytes
# [  5]   4.00-5.00   sec  90.0 MBytes   755 Mbits/sec    0   2.14 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   776 Mbits/sec    2   2.32 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   2.49 MBytes
# [  5]   7.00-8.00   sec  91.2 MBytes   765 Mbits/sec    2   2.64 MBytes
# [  5]   8.00-9.00   sec  91.2 MBytes   765 Mbits/sec    0   2.79 MBytes
# [  5]   9.00-10.00  sec  91.2 MBytes   765 Mbits/sec    0   2.94 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   918 MBytes   770 Mbits/sec   11             sender
# [  5]   0.00-10.05  sec   917 MBytes   766 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-7: 798 Mbits/sec
# Full output from bandwidth-measurement-ds-gnsh9 to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.230.44 port 46600 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.9 MBytes   804 Mbits/sec    0   3.13 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.13 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# [  5]   7.00-8.00   sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.13 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   938 MBytes   787 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   938 MBytes   784 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-1 to k8s-worker-4: 804 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.231.226 port 43280 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.8 MBytes   803 Mbits/sec    0   3.15 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  10.0 MBytes  83.8 Mbits/sec    2   8.69 KBytes
# [  5]   9.00-10.00  sec  85.0 MBytes   714 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   842 MBytes   706 Mbits/sec    2             sender
# [  5]   0.00-10.03  sec   841 MBytes   703 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-3: 803 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.231.226 port 40988 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.4 MBytes   800 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   935 MBytes   785 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   935 MBytes   782 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-1: 800 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.231.226 port 56548 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  90.9 MBytes   762 Mbits/sec    8    982 KBytes
# [  5]   1.00-2.00   sec  88.6 MBytes   743 Mbits/sec    0   1.31 MBytes
# [  5]   2.00-3.00   sec  87.5 MBytes   734 Mbits/sec    0   1.58 MBytes
# [  5]   3.00-4.00   sec  90.0 MBytes   755 Mbits/sec    0   1.82 MBytes
# [  5]   4.00-5.00   sec  88.8 MBytes   744 Mbits/sec    0   2.03 MBytes
# [  5]   5.00-6.00   sec  87.5 MBytes   734 Mbits/sec    0   2.21 MBytes
# [  5]   6.00-7.00   sec  88.8 MBytes   744 Mbits/sec    0   2.39 MBytes
# [  5]   7.00-8.00   sec  87.5 MBytes   734 Mbits/sec    0   2.55 MBytes
# [  5]   8.00-9.00   sec  87.5 MBytes   734 Mbits/sec    0   2.73 MBytes
# [  5]   9.00-10.00  sec  87.5 MBytes   734 Mbits/sec    0   3.03 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   884 MBytes   742 Mbits/sec    8             sender
# [  5]   0.00-10.03  sec   884 MBytes   740 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-5: 762 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.231.226 port 55656 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  90.4 MBytes   758 Mbits/sec   17    886 KBytes
# [  5]   1.00-2.00   sec  89.0 MBytes   747 Mbits/sec    0   1.25 MBytes
# [  5]   2.00-3.00   sec  87.5 MBytes   734 Mbits/sec    1   1.53 MBytes
# [  5]   3.00-4.00   sec  88.8 MBytes   744 Mbits/sec    0   1.77 MBytes
# [  5]   4.00-5.00   sec  88.8 MBytes   744 Mbits/sec    0   1.99 MBytes
# [  5]   5.00-6.00   sec  87.5 MBytes   734 Mbits/sec    0   2.17 MBytes
# [  5]   6.00-7.00   sec  88.8 MBytes   744 Mbits/sec    0   2.35 MBytes
# [  5]   7.00-8.00   sec  87.5 MBytes   734 Mbits/sec    0   2.52 MBytes
# [  5]   8.00-9.00   sec  87.5 MBytes   734 Mbits/sec    0   2.67 MBytes
# [  5]   9.00-10.00  sec  87.5 MBytes   734 Mbits/sec    0   2.93 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   883 MBytes   741 Mbits/sec   18             sender
# [  5]   0.00-10.03  sec   883 MBytes   738 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-9: 758 Mbits/sec
# Full output from bandwidth-measurement-ds-nrznp to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.231.226 port 48794 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  90.0 MBytes   755 Mbits/sec    9    886 KBytes
# [  5]   1.00-2.00   sec  88.6 MBytes   744 Mbits/sec    0   1.24 MBytes
# [  5]   2.00-3.00   sec  87.5 MBytes   734 Mbits/sec    0   1.53 MBytes
# [  5]   3.00-4.00   sec  90.0 MBytes   755 Mbits/sec    0   1.77 MBytes
# [  5]   4.00-5.00   sec  87.5 MBytes   734 Mbits/sec    0   1.99 MBytes
# [  5]   5.00-6.00   sec  87.5 MBytes   734 Mbits/sec    0   2.18 MBytes
# [  5]   6.00-7.00   sec  88.8 MBytes   744 Mbits/sec    0   2.36 MBytes
# [  5]   7.00-8.00   sec  88.8 MBytes   744 Mbits/sec    0   2.52 MBytes
# [  5]   8.00-9.00   sec  86.2 MBytes   724 Mbits/sec    0   2.67 MBytes
# [  5]   9.00-10.00  sec  88.8 MBytes   745 Mbits/sec    0   3.04 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   884 MBytes   741 Mbits/sec    9             sender
# [  5]   0.00-10.03  sec   883 MBytes   738 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-8 to k8s-worker-6: 755 Mbits/sec
# Error executing command in pod bandwidth-measurement-ds-nrznp: (0)
# Reason: Handshake status 500 Internal Server Error -+-+- {'audit-id': '65b76e04-cf08-414f-86d4-504fc38559a1', 'cache-control': 'no-cache, private', 'content-type': 'application/json', 'date': 'Tue, 12 Nov 2024 04:34:16 GMT', 'content-length': '122'} -+-+- b'{"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"etcdserver: request timed out","code":500}\n'
#
# Error executing command in pod bandwidth-measurement-ds-nrznp: (0)
# Reason: Handshake status 500 Internal Server Error -+-+- {'audit-id': '9221f1be-af5c-4d8a-ab02-dfef6779e564', 'cache-control': 'no-cache, private', 'content-type': 'application/json', 'date': 'Tue, 12 Nov 2024 04:34:16 GMT', 'content-length': '122'} -+-+- b'{"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"etcdserver: request timed out","code":500}\n'
#
# Error executing command in pod bandwidth-measurement-ds-nrznp: (0)
# Reason: Handshake status 500 Internal Server Error -+-+- {'audit-id': 'fef9a5d8-1fdd-4584-a1d5-38982995d480', 'cache-control': 'no-cache, private', 'content-type': 'application/json', 'date': 'Tue, 12 Nov 2024 04:34:16 GMT', 'content-length': '122'} -+-+- b'{"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"etcdserver: request timed out","code":500}\n'
#
# Error executing command in pod bandwidth-measurement-ds-p2vgl: (0)
# Reason: Handshake status 500 Internal Server Error -+-+- {'audit-id': '5f2c0684-f957-434f-a920-94e57975b8ec', 'cache-control': 'no-cache, private', 'content-type': 'application/json', 'date': 'Tue, 12 Nov 2024 04:34:30 GMT', 'content-length': '122'} -+-+- b'{"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"etcdserver: request timed out","code":500}\n'
#
# Error executing command in pod bandwidth-measurement-ds-p2vgl: (0)
# Reason: Handshake status 500 Internal Server Error -+-+- {'audit-id': '0c86d318-66fb-4595-afb4-206f6effd4a0', 'cache-control': 'no-cache, private', 'content-type': 'application/json', 'date': 'Tue, 12 Nov 2024 04:34:30 GMT', 'content-length': '122'} -+-+- b'{"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"etcdserver: request timed out","code":500}\n'
#
# Error executing command in pod bandwidth-measurement-ds-p2vgl: (0)
# Reason: Handshake status 500 Internal Server Error -+-+- {'audit-id': '487506e4-131d-4ada-8757-9535efc249d5', 'cache-control': 'no-cache, private', 'content-type': 'application/json', 'date': 'Tue, 12 Nov 2024 04:34:30 GMT', 'content-length': '122'} -+-+- b'{"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"etcdserver: request timed out","code":500}\n'
#
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.18.232 port 34298 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  77.5 MBytes   650 Mbits/sec   11    860 KBytes
# [  5]   1.00-2.00   sec  68.2 MBytes   572 Mbits/sec    0   1.15 MBytes
# [  5]   2.00-3.00   sec  68.8 MBytes   577 Mbits/sec    0   1.39 MBytes
# [  5]   3.00-4.00   sec  68.8 MBytes   577 Mbits/sec    0   1.60 MBytes
# [  5]   4.00-5.00   sec  70.0 MBytes   587 Mbits/sec    0   1.79 MBytes
# [  5]   5.00-6.00   sec  67.5 MBytes   566 Mbits/sec    0   1.95 MBytes
# [  5]   6.00-7.00   sec  67.5 MBytes   566 Mbits/sec    1   2.10 MBytes
# [  5]   7.00-8.00   sec  68.8 MBytes   577 Mbits/sec    0   2.23 MBytes
# [  5]   8.00-9.00   sec  67.5 MBytes   566 Mbits/sec    0   2.37 MBytes
# [  5]   9.00-10.00  sec  68.8 MBytes   577 Mbits/sec    0   2.49 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   693 MBytes   582 Mbits/sec   12             sender
# [  5]   0.00-10.05  sec   692 MBytes   578 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-6: 650 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.18.232 port 41960 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  65.8 MBytes   552 Mbits/sec    7    773 KBytes
# [  5]   1.00-2.00   sec  65.7 MBytes   551 Mbits/sec    0   1.08 MBytes
# [  5]   2.00-3.00   sec  68.8 MBytes   577 Mbits/sec    0   1.33 MBytes
# [  5]   3.00-4.00   sec  68.8 MBytes   577 Mbits/sec    0   1.54 MBytes
# [  5]   4.00-5.00   sec  68.8 MBytes   577 Mbits/sec    2   1.72 MBytes
# [  5]   5.00-6.00   sec  68.8 MBytes   577 Mbits/sec    0   1.90 MBytes
# [  5]   6.00-7.00   sec  67.5 MBytes   566 Mbits/sec    0   2.05 MBytes
# [  5]   7.00-8.00   sec  68.8 MBytes   577 Mbits/sec    0   2.20 MBytes
# [  5]   8.00-9.00   sec  67.5 MBytes   566 Mbits/sec    0   2.33 MBytes
# [  5]   9.00-10.00  sec  67.5 MBytes   566 Mbits/sec    0   2.46 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   678 MBytes   569 Mbits/sec    9             sender
# [  5]   0.00-10.05  sec   677 MBytes   566 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-9: 552 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.18.232 port 52922 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  63.6 MBytes   533 Mbits/sec    4    773 KBytes
# [  5]   1.00-2.00   sec  66.4 MBytes   557 Mbits/sec    0   1.08 MBytes
# [  5]   2.00-3.00   sec  68.8 MBytes   577 Mbits/sec    0   1.33 MBytes
# [  5]   3.00-4.00   sec  68.8 MBytes   577 Mbits/sec    0   1.55 MBytes
# [  5]   4.00-5.00   sec  68.8 MBytes   577 Mbits/sec    1   1.73 MBytes
# [  5]   5.00-6.00   sec  67.5 MBytes   566 Mbits/sec    0   1.91 MBytes
# [  5]   6.00-7.00   sec  68.8 MBytes   577 Mbits/sec    0   2.06 MBytes
# [  5]   7.00-8.00   sec  68.8 MBytes   577 Mbits/sec    0   2.21 MBytes
# [  5]   8.00-9.00   sec  67.5 MBytes   566 Mbits/sec    0   2.34 MBytes
# [  5]   9.00-10.00  sec  67.5 MBytes   566 Mbits/sec    0   2.47 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   676 MBytes   567 Mbits/sec    5             sender
# [  5]   0.00-10.04  sec   676 MBytes   565 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-2: 533 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.18.232 port 36138 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.6 MBytes   802 Mbits/sec    0   3.17 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.17 MBytes
# [  5]   2.00-3.00   sec  91.2 MBytes   765 Mbits/sec    0   3.17 MBytes
# [  5]   3.00-4.00   sec  91.2 MBytes   765 Mbits/sec    0   3.17 MBytes
# [  5]   4.00-5.00   sec  91.2 MBytes   765 Mbits/sec    0   3.17 MBytes
# [  5]   5.00-6.00   sec  91.2 MBytes   765 Mbits/sec    0   3.17 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   786 Mbits/sec    0   3.17 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    2   3.17 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   775 Mbits/sec    0   3.17 MBytes
# [  5]   9.00-10.00  sec  91.2 MBytes   766 Mbits/sec    0   3.17 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   923 MBytes   774 Mbits/sec    2             sender
# [  5]   0.00-10.03  sec   923 MBytes   772 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-7: 802 Mbits/sec
# Full output from bandwidth-measurement-ds-p2vgl to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.18.232 port 54910 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  94.9 MBytes   796 Mbits/sec    8   1.97 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   2.17 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   2.35 MBytes
# [  5]   3.00-4.00   sec  91.2 MBytes   765 Mbits/sec    0   2.52 MBytes
# [  5]   4.00-5.00   sec  91.2 MBytes   765 Mbits/sec    0   2.68 MBytes
# [  5]   5.00-6.00   sec  92.5 MBytes   776 Mbits/sec    6   2.82 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   2.96 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   3.02 MBytes
# [  5]   8.00-9.00   sec  92.5 MBytes   776 Mbits/sec    0   3.02 MBytes
# [  5]   9.00-10.00  sec  92.5 MBytes   776 Mbits/sec    0   3.02 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   925 MBytes   776 Mbits/sec   14             sender
# [  5]   0.00-10.03  sec   924 MBytes   773 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-5 to k8s-worker-4: 796 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.251.65 port 38952 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.4 MBytes   800 Mbits/sec    1   1.49 MBytes
# [  5]   1.00-2.00   sec  93.8 MBytes   786 Mbits/sec    0   1.74 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   1.97 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   2.17 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   2.36 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   2.53 MBytes
# [  5]   6.00-7.00   sec  92.5 MBytes   776 Mbits/sec    0   2.69 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   2.84 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   3.03 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.03 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   933 MBytes   783 Mbits/sec    1             sender
# [  5]   0.00-10.03  sec   932 MBytes   779 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-3: 800 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.251.65 port 40076 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  87.3 MBytes   733 Mbits/sec   16    852 KBytes
# [  5]   1.00-2.00   sec  85.5 MBytes   718 Mbits/sec    0   1.20 MBytes
# [  5]   2.00-3.00   sec  86.2 MBytes   724 Mbits/sec    0   1.49 MBytes
# [  5]   3.00-4.00   sec  86.2 MBytes   724 Mbits/sec    0   1.74 MBytes
# [  5]   4.00-5.00   sec  82.5 MBytes   692 Mbits/sec    0   1.94 MBytes
# [  5]   5.00-6.00   sec  85.0 MBytes   713 Mbits/sec    0   2.13 MBytes
# [  5]   6.00-7.00   sec  85.0 MBytes   713 Mbits/sec    0   2.30 MBytes
# [  5]   7.00-8.00   sec  83.8 MBytes   703 Mbits/sec    0   2.46 MBytes
# [  5]   8.00-9.00   sec  83.8 MBytes   703 Mbits/sec    0   2.61 MBytes
# [  5]   9.00-10.00  sec  85.0 MBytes   713 Mbits/sec    0   3.04 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   850 MBytes   713 Mbits/sec   16             sender
# [  5]   0.00-10.04  sec   850 MBytes   710 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-1: 733 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-nrznp:
# Connecting to host 192.168.231.226, port 5201
# [  5] local 192.168.251.65 port 56998 connected to 192.168.231.226 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  87.3 MBytes   733 Mbits/sec   11    886 KBytes
# [  5]   1.00-2.00   sec  86.0 MBytes   722 Mbits/sec    0   1.23 MBytes
# [  5]   2.00-3.00   sec  85.0 MBytes   713 Mbits/sec    1   1.49 MBytes
# [  5]   3.00-4.00   sec  86.2 MBytes   724 Mbits/sec    0   1.74 MBytes
# [  5]   4.00-5.00   sec  81.2 MBytes   682 Mbits/sec    0   1.94 MBytes
# [  5]   5.00-6.00   sec  85.0 MBytes   713 Mbits/sec    0   2.13 MBytes
# [  5]   6.00-7.00   sec  85.0 MBytes   713 Mbits/sec    0   2.31 MBytes
# [  5]   7.00-8.00   sec  85.0 MBytes   713 Mbits/sec    0   2.47 MBytes
# [  5]   8.00-9.00   sec  83.8 MBytes   702 Mbits/sec    0   2.61 MBytes
# [  5]   9.00-10.00  sec  85.0 MBytes   713 Mbits/sec    0   2.83 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   850 MBytes   713 Mbits/sec   12             sender
# [  5]   0.00-10.04  sec   849 MBytes   709 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-8: 733 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-p2vgl:
# Connecting to host 192.168.18.232, port 5201
# [  5] local 192.168.251.65 port 55412 connected to 192.168.18.232 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  86.1 MBytes   722 Mbits/sec   13    834 KBytes
# [  5]   1.00-2.00   sec  85.4 MBytes   717 Mbits/sec    0   1.20 MBytes
# [  5]   2.00-3.00   sec  85.0 MBytes   713 Mbits/sec    1   1.47 MBytes
# [  5]   3.00-4.00   sec  86.2 MBytes   724 Mbits/sec    0   1.71 MBytes
# [  5]   4.00-5.00   sec  82.5 MBytes   692 Mbits/sec    0   1.93 MBytes
# [  5]   5.00-6.00   sec  85.0 MBytes   713 Mbits/sec    0   2.11 MBytes
# [  5]   6.00-7.00   sec  85.0 MBytes   713 Mbits/sec    0   2.29 MBytes
# [  5]   7.00-8.00   sec  83.8 MBytes   703 Mbits/sec    0   2.44 MBytes
# [  5]   8.00-9.00   sec  83.8 MBytes   703 Mbits/sec    0   2.60 MBytes
# [  5]   9.00-10.00  sec  85.0 MBytes   713 Mbits/sec    0   2.77 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   848 MBytes   711 Mbits/sec   14             sender
# [  5]   0.00-10.04  sec   848 MBytes   708 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-5: 722 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.251.65 port 50632 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  87.9 MBytes   737 Mbits/sec   21    895 KBytes
# [  5]   1.00-2.00   sec  85.2 MBytes   715 Mbits/sec    0   1.24 MBytes
# [  5]   2.00-3.00   sec  86.2 MBytes   724 Mbits/sec    0   1.52 MBytes
# [  5]   3.00-4.00   sec  86.2 MBytes   724 Mbits/sec    5   1.75 MBytes
# [  5]   4.00-5.00   sec  87.5 MBytes   734 Mbits/sec    0   1.96 MBytes
# [  5]   5.00-6.00   sec  86.2 MBytes   724 Mbits/sec    0   2.15 MBytes
# [  5]   6.00-7.00   sec  86.2 MBytes   724 Mbits/sec    0   2.33 MBytes
# [  5]   7.00-8.00   sec  86.2 MBytes   724 Mbits/sec    0   2.49 MBytes
# [  5]   8.00-9.00   sec  86.2 MBytes   724 Mbits/sec    0   2.64 MBytes
# [  5]   9.00-10.00  sec  88.8 MBytes   744 Mbits/sec    0   2.78 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   867 MBytes   727 Mbits/sec   26             sender
# [  5]   0.00-10.03  sec   866 MBytes   724 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-6: 737 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.251.65 port 56136 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  87.5 MBytes   734 Mbits/sec   16    878 KBytes
# [  5]   1.00-2.00   sec  85.9 MBytes   721 Mbits/sec    0   1.23 MBytes
# [  5]   2.00-3.00   sec  86.2 MBytes   724 Mbits/sec    0   1.51 MBytes
# [  5]   3.00-4.00   sec  86.2 MBytes   724 Mbits/sec    0   1.76 MBytes
# [  5]   4.00-5.00   sec  87.5 MBytes   734 Mbits/sec    0   1.97 MBytes
# [  5]   5.00-6.00   sec  86.2 MBytes   724 Mbits/sec    0   2.16 MBytes
# [  5]   6.00-7.00   sec  86.2 MBytes   724 Mbits/sec    0   2.33 MBytes
# [  5]   7.00-8.00   sec  87.5 MBytes   734 Mbits/sec    0   2.49 MBytes
# [  5]   8.00-9.00   sec  86.2 MBytes   723 Mbits/sec    0   2.65 MBytes
# [  5]   9.00-10.00  sec  88.8 MBytes   744 Mbits/sec    0   3.04 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   868 MBytes   728 Mbits/sec   16             sender
# [  5]   0.00-10.03  sec   868 MBytes   726 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-9 to k8s-worker-2: 734 Mbits/sec
# Full output from bandwidth-measurement-ds-r7ftn to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.251.65 port 45112 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  86.8 MBytes   728 Mbits/sec   18    878 KBytes
# [  5]   1.00-2.00   sec  85.4 MBytes   717 Mbits/sec    0   1.22 MBytes
# [  5]   2.00-3.00   sec  85.0 MBytes   713 Mbits/sec    0   1.51 MBytes
# [  5]   3.00-4.00   sec  87.5 MBytes   734 Mbits/sec    0   1.75 MBytes
# ...
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.15 MBytes
# [  5]   5.00-6.00   sec  91.2 MBytes   765 Mbits/sec    0   3.15 MBytes
# [  5]   6.00-7.00   sec  91.2 MBytes   765 Mbits/sec    0   3.15 MBytes
# [  5]   7.00-8.00   sec  88.8 MBytes   745 Mbits/sec    0   3.15 MBytes
# [  5]   8.00-9.00   sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# [  5]   9.00-10.00  sec  90.0 MBytes   755 Mbits/sec    0   3.15 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   917 MBytes   769 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   917 MBytes   767 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-7 to k8s-worker-6: 803 Mbits/sec
# Full output from bandwidth-measurement-ds-z29qn to bandwidth-measurement-ds-r7ftn:
# Connecting to host 192.168.251.65, port 5201
# [  5] local 192.168.5.12 port 44670 connected to 192.168.251.65 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  95.8 MBytes   803 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  91.2 MBytes   765 Mbits/sec    1   3.14 MBytes
# [  5]   7.00-8.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  88.8 MBytes   744 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  91.2 MBytes   766 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   917 MBytes   769 Mbits/sec    1             sender
# [  5]   0.00-10.03  sec   916 MBytes   766 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-7 to k8s-worker-9: 803 Mbits/sec
# Full output from bandwidth-measurement-ds-z29qn to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.5.12 port 57418 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  96.5 MBytes   809 Mbits/sec    0   3.14 MBytes
# [  5]   1.00-2.00   sec  91.2 MBytes   765 Mbits/sec    0   3.14 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   3.14 MBytes
# [  5]   3.00-4.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   3.14 MBytes
# [  5]   5.00-6.00   sec  91.2 MBytes   765 Mbits/sec    0   3.14 MBytes
# [  5]   6.00-7.00   sec  91.2 MBytes   766 Mbits/sec    0   3.14 MBytes
# [  5]   7.00-8.00   sec  90.0 MBytes   755 Mbits/sec    0   3.14 MBytes
# [  5]   8.00-9.00   sec  88.8 MBytes   745 Mbits/sec    0   3.14 MBytes
# [  5]   9.00-10.00  sec  91.2 MBytes   765 Mbits/sec    0   3.14 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   919 MBytes   771 Mbits/sec    0             sender
# [  5]   0.00-10.03  sec   919 MBytes   768 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-7 to k8s-worker-2: 809 Mbits/sec
# Full output from bandwidth-measurement-ds-z29qn to bandwidth-measurement-ds-z4wqx:
# Connecting to host 192.168.79.76, port 5201
# [  5] local 192.168.5.12 port 54918 connected to 192.168.79.76 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  96.0 MBytes   805 Mbits/sec    1    947 KBytes
# [  5]   1.00-2.00   sec  93.5 MBytes   784 Mbits/sec    0   1.31 MBytes
# [  5]   2.00-3.00   sec  93.8 MBytes   786 Mbits/sec    0   1.60 MBytes
# [  5]   3.00-4.00   sec  93.8 MBytes   786 Mbits/sec    0   1.85 MBytes
# [  5]   4.00-5.00   sec  92.5 MBytes   776 Mbits/sec    0   2.07 MBytes
# [  5]   5.00-6.00   sec  93.8 MBytes   786 Mbits/sec    0   2.26 MBytes
# [  5]   6.00-7.00   sec  93.8 MBytes   787 Mbits/sec    0   2.44 MBytes
# [  5]   7.00-8.00   sec  92.5 MBytes   776 Mbits/sec    0   2.61 MBytes
# [  5]   8.00-9.00   sec  93.8 MBytes   786 Mbits/sec    0   2.77 MBytes
# [  5]   9.00-10.00  sec  93.8 MBytes   786 Mbits/sec    0   3.03 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   937 MBytes   786 Mbits/sec    1             sender
# [  5]   0.00-10.03  sec   936 MBytes   783 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-7 to k8s-worker-4: 805 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-gnsh9:
# Connecting to host 192.168.230.44, port 5201
# [  5] local 192.168.79.76 port 57748 connected to 192.168.230.44 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  86.7 MBytes   727 Mbits/sec    6    895 KBytes
# [  5]   1.00-2.00   sec  84.0 MBytes   705 Mbits/sec    0   1.24 MBytes
# [  5]   2.00-3.00   sec  82.5 MBytes   692 Mbits/sec    0   1.51 MBytes
# [  5]   3.00-4.00   sec  81.2 MBytes   682 Mbits/sec    0   1.74 MBytes
# [  5]   4.00-5.00   sec  83.8 MBytes   703 Mbits/sec    0   1.94 MBytes
# [  5]   5.00-6.00   sec  83.8 MBytes   703 Mbits/sec    0   2.13 MBytes
# [  5]   6.00-7.00   sec  82.5 MBytes   692 Mbits/sec    0   2.30 MBytes
# [  5]   7.00-8.00   sec  85.0 MBytes   713 Mbits/sec    0   2.46 MBytes
# [  5]   8.00-9.00   sec  85.0 MBytes   713 Mbits/sec    0   2.66 MBytes
# [  5]   9.00-10.00  sec  86.2 MBytes   724 Mbits/sec    0   3.03 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   841 MBytes   705 Mbits/sec    6             sender
# [  5]   0.00-10.03  sec   841 MBytes   703 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-1: 727 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-6dldb:
# Connecting to host 192.168.69.209, port 5201
# [  5] local 192.168.79.76 port 39974 connected to 192.168.69.209 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  86.6 MBytes   726 Mbits/sec    2    904 KBytes
# [  5]   1.00-2.00   sec  82.7 MBytes   694 Mbits/sec    1   1.23 MBytes
# [  5]   2.00-3.00   sec  82.5 MBytes   692 Mbits/sec    1   1.49 MBytes
# [  5]   3.00-4.00   sec  81.2 MBytes   682 Mbits/sec    0   1.71 MBytes
# [  5]   4.00-5.00   sec  82.5 MBytes   692 Mbits/sec    0   1.93 MBytes
# [  5]   5.00-6.00   sec  83.8 MBytes   703 Mbits/sec    0   2.11 MBytes
# [  5]   6.00-7.00   sec  82.5 MBytes   692 Mbits/sec    0   2.28 MBytes
# [  5]   7.00-8.00   sec  83.8 MBytes   703 Mbits/sec    0   2.44 MBytes
# [  5]   8.00-9.00   sec  85.0 MBytes   713 Mbits/sec    0   2.60 MBytes
# [  5]   9.00-10.00  sec  86.2 MBytes   724 Mbits/sec    0   2.74 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   837 MBytes   702 Mbits/sec    4             sender
# [  5]   0.00-10.03  sec   836 MBytes   699 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-3: 726 Mbits/sec
# Error executing command in pod bandwidth-measurement-ds-z4wqx: (0)
# Reason: Handshake status 500 Internal Server Error -+-+- {'audit-id': '6271e763-3a6d-4d73-b8cd-cb63f24034e6', 'cache-control': 'no-cache, private', 'content-type': 'application/json', 'date': 'Tue, 12 Nov 2024 04:37:25 GMT', 'content-length': '122'} -+-+- b'{"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"etcdserver: request timed out","code":500}\n'
#
# Error executing command in pod bandwidth-measurement-ds-z4wqx: (0)
# Reason: Handshake status 500 Internal Server Error -+-+- {'audit-id': '52a199dc-d410-4196-9269-f91f1a3f4170', 'cache-control': 'no-cache, private', 'content-type': 'application/json', 'date': 'Tue, 12 Nov 2024 04:37:25 GMT', 'content-length': '122'} -+-+- b'{"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"etcdserver: request timed out","code":500}\n'
#
# Error executing command in pod bandwidth-measurement-ds-z4wqx: (0)
# Reason: Handshake status 500 Internal Server Error -+-+- {'audit-id': '7c0aaca8-9b02-46f0-b4db-2469db49fd73', 'cache-control': 'no-cache, private', 'content-type': 'application/json', 'date': 'Tue, 12 Nov 2024 04:37:25 GMT', 'content-length': '122'} -+-+- b'{"kind":"Status","apiVersion":"v1","metadata":{},"status":"Failure","message":"etcdserver: request timed out","code":500}\n'
#
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-vf5qp:
# Connecting to host 192.168.140.9, port 5201
# [  5] local 192.168.79.76 port 55382 connected to 192.168.140.9 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  74.2 MBytes   623 Mbits/sec   11    799 KBytes
# [  5]   1.00-2.00   sec  76.0 MBytes   638 Mbits/sec    0   1.13 MBytes
# [  5]   2.00-3.00   sec  73.8 MBytes   619 Mbits/sec    0   1.40 MBytes
# [  5]   3.00-4.00   sec  76.2 MBytes   640 Mbits/sec    0   1.63 MBytes
# [  5]   4.00-5.00   sec  75.0 MBytes   629 Mbits/sec    2   1.81 MBytes
# [  5]   5.00-6.00   sec  78.8 MBytes   661 Mbits/sec    0   1.99 MBytes
# [  5]   6.00-7.00   sec  77.5 MBytes   650 Mbits/sec    0   2.16 MBytes
# [  5]   7.00-8.00   sec  76.2 MBytes   640 Mbits/sec    0   2.32 MBytes
# [  5]   8.00-9.00   sec  75.0 MBytes   629 Mbits/sec    0   2.46 MBytes
# [  5]   9.00-10.00  sec  77.5 MBytes   650 Mbits/sec    0   2.60 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   760 MBytes   638 Mbits/sec   13             sender
# [  5]   0.00-10.03  sec   759 MBytes   635 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-2: 623 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-rfvj2:
# Connecting to host 192.168.227.155, port 5201
# [  5] local 192.168.79.76 port 39564 connected to 192.168.227.155 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  62.2 MBytes   521 Mbits/sec   10    756 KBytes
# [  5]   1.00-2.00   sec  72.5 MBytes   608 Mbits/sec    0   1.09 MBytes
# [  5]   2.00-3.00   sec  75.0 MBytes   629 Mbits/sec    0   1.37 MBytes
# [  5]   3.00-4.00   sec  76.2 MBytes   640 Mbits/sec    1   1.59 MBytes
# [  5]   4.00-5.00   sec  75.0 MBytes   629 Mbits/sec    0   1.78 MBytes
# [  5]   5.00-6.00   sec  77.5 MBytes   650 Mbits/sec    0   1.98 MBytes
# [  5]   6.00-7.00   sec  78.8 MBytes   661 Mbits/sec    0   2.15 MBytes
# [  5]   7.00-8.00   sec  76.2 MBytes   640 Mbits/sec    0   2.30 MBytes
# [  5]   8.00-9.00   sec  75.0 MBytes   629 Mbits/sec    0   2.44 MBytes
# [  5]   9.00-10.00  sec  76.2 MBytes   640 Mbits/sec    0   2.59 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   745 MBytes   625 Mbits/sec   11             sender
# [  5]   0.00-10.03  sec   744 MBytes   622 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-6: 521 Mbits/sec
# Full output from bandwidth-measurement-ds-z4wqx to bandwidth-measurement-ds-z29qn:
# Connecting to host 192.168.5.12, port 5201
# [  5] local 192.168.79.76 port 37690 connected to 192.168.5.12 port 5201
# [ ID] Interval           Transfer     Bitrate         Retr  Cwnd
# [  5]   0.00-1.00   sec  90.6 MBytes   760 Mbits/sec    4   1.20 MBytes
# [  5]   1.00-2.00   sec  77.5 MBytes   650 Mbits/sec    0   1.46 MBytes
# [  5]   2.00-3.00   sec  75.0 MBytes   629 Mbits/sec    1   1.66 MBytes
# [  5]   3.00-4.00   sec  76.2 MBytes   640 Mbits/sec    0   1.86 MBytes
# [  5]   4.00-5.00   sec  75.0 MBytes   629 Mbits/sec    0   2.04 MBytes
# [  5]   5.00-6.00   sec  77.5 MBytes   650 Mbits/sec    0   2.21 MBytes
# [  5]   6.00-7.00   sec  77.5 MBytes   650 Mbits/sec    0   2.36 MBytes
# [  5]   7.00-8.00   sec  76.2 MBytes   640 Mbits/sec    0   2.49 MBytes
# [  5]   8.00-9.00   sec  76.2 MBytes   639 Mbits/sec    0   2.63 MBytes
# [  5]   9.00-10.00  sec  76.2 MBytes   640 Mbits/sec    0   3.04 MBytes
# - - - - - - - - - - - - - - - - - - - - - - - - -
# [ ID] Interval           Transfer     Bitrate         Retr
# [  5]   0.00-10.00  sec   778 MBytes   653 Mbits/sec    5             sender
# [  5]   0.00-10.03  sec   778 MBytes   651 Mbits/sec                  receiver
#
# iperf Done.
#
# Bandwidth from k8s-worker-4 to k8s-worker-7: 760 Mbits/sec
# {'k8s-worker-3': {'k8s-worker-5': '701 Mbits/sec', 'k8s-worker-1': '567 Mbits/sec', 'k8s-worker-8': '544 Mbits/sec', 'k8s-worker-6': '595 Mbits/sec', 'k8s-worker-9': '547 Mbits/sec', 'k8s-worker-2': '690 Mbits/sec', 'k8s-worker-7': '739 Mbits/sec', 'k8s-worker-4': '740 Mbits/sec'}, 'k8s-worker-1': {'k8s-worker-3': '796 Mbits/sec', 'k8s-worker-8': '784 Mbits/sec', 'k8s-worker-5': '788 Mbits/sec', 'k8s-worker-9': '769 Mbits/sec', 'k8s-worker-6': '797 Mbits/sec', 'k8s-worker-2': '793 Mbits/sec', 'k8s-worker-7': '798 Mbits/sec', 'k8s-worker-4': '804 Mbits/sec'}, 'k8s-worker-8': {'k8s-worker-3': '803 Mbits/sec', 'k8s-worker-1': '800 Mbits/sec', 'k8s-worker-5': '762 Mbits/sec', 'k8s-worker-9': '758 Mbits/sec', 'k8s-worker-6': '755 Mbits/sec', 'k8s-worker-2': 'Error', 'k8s-worker-4': 'Error', 'k8s-worker-7': 'Error'}, 'k8s-worker-5': {'k8s-worker-8': 'Error', 'k8s-worker-1': 'Error', 'k8s-worker-3': 'Error', 'k8s-worker-6': '650 Mbits/sec', 'k8s-worker-9': '552 Mbits/sec', 'k8s-worker-2': '533 Mbits/sec', 'k8s-worker-7': '802 Mbits/sec', 'k8s-worker-4': '796 Mbits/sec'}, 'k8s-worker-9': {'k8s-worker-3': '800 Mbits/sec', 'k8s-worker-1': '733 Mbits/sec', 'k8s-worker-8': '733 Mbits/sec', 'k8s-worker-5': '722 Mbits/sec', 'k8s-worker-6': '737 Mbits/sec', 'k8s-worker-2': '734 Mbits/sec', 'k8s-worker-7': '728 Mbits/sec', 'k8s-worker-4': '803 Mbits/sec'}, 'k8s-worker-6': {'k8s-worker-3': '796 Mbits/sec', 'k8s-worker-1': '800 Mbits/sec', 'k8s-worker-8': '527 Mbits/sec', 'k8s-worker-5': '521 Mbits/sec', 'k8s-worker-9': '754 Mbits/sec', 'k8s-worker-2': '553 Mbits/sec', 'k8s-worker-4': '744 Mbits/sec', 'k8s-worker-7': '442 Mbits/sec'}, 'k8s-worker-2': {'k8s-worker-3': '764 Mbits/sec', 'k8s-worker-1': '772 Mbits/sec', 'k8s-worker-8': '773 Mbits/sec', 'k8s-worker-5': '776 Mbits/sec', 'k8s-worker-9': '775 Mbits/sec', 'k8s-worker-6': '779 Mbits/sec', 'k8s-worker-7': '805 Mbits/sec', 'k8s-worker-4': '813 Mbits/sec'}, 'k8s-worker-7': {'k8s-worker-3': '807 Mbits/sec', 'k8s-worker-8': '749 Mbits/sec', 'k8s-worker-1': '764 Mbits/sec', 'k8s-worker-5': '769 Mbits/sec', 'k8s-worker-6': '803 Mbits/sec', 'k8s-worker-9': '803 Mbits/sec', 'k8s-worker-2': '809 Mbits/sec', 'k8s-worker-4': '805 Mbits/sec'}, 'k8s-worker-4': {'k8s-worker-1': '727 Mbits/sec', 'k8s-worker-3': '726 Mbits/sec', 'k8s-worker-9': 'Error', 'k8s-worker-8': 'Error', 'k8s-worker-5': 'Error', 'k8s-worker-2': '623 Mbits/sec', 'k8s-worker-6': '521 Mbits/sec', 'k8s-worker-7': '760 Mbits/sec'}}

# %%
import pandas as pd

# Convert the nested dictionary into a pandas DataFrame
df = pd.DataFrame(bandwidth_results)

# Transpose the DataFrame to align the source and destination workers as per convention
df = df.T

# Fill diagonal with 0's for self-latency (optional, if desired for clarity)
for worker in df.columns:
    df.at[worker, worker] = 0

# Save the DataFrame to a CSV file, and add the date, hour and minute to the file name
import datetime
now = datetime.datetime.now()
filename = f"bandwidth_results_{now.strftime('%Y-%m-%d_%H-%M')}.csv"
df.to_csv("/home/ubuntu/iDynamics/iBandwidth/measurer/data/"+filename)
df
# Out:
#                k8s-worker-5   k8s-worker-1   k8s-worker-8   k8s-worker-6  \
# k8s-worker-3  701 Mbits/sec  567 Mbits/sec  544 Mbits/sec  595 Mbits/sec
# k8s-worker-1  788 Mbits/sec              0  784 Mbits/sec  797 Mbits/sec
# k8s-worker-8  762 Mbits/sec  800 Mbits/sec              0  755 Mbits/sec
# k8s-worker-5              0          Error          Error  650 Mbits/sec
# k8s-worker-9  722 Mbits/sec  733 Mbits/sec  733 Mbits/sec  737 Mbits/sec
# k8s-worker-6  521 Mbits/sec  800 Mbits/sec  527 Mbits/sec              0
# k8s-worker-2  776 Mbits/sec  772 Mbits/sec  773 Mbits/sec  779 Mbits/sec
# k8s-worker-7  769 Mbits/sec  764 Mbits/sec  749 Mbits/sec  803 Mbits/sec
# k8s-worker-4          Error  727 Mbits/sec          Error  521 Mbits/sec
#
#                k8s-worker-9   k8s-worker-2   k8s-worker-7   k8s-worker-4  \
# k8s-worker-3  547 Mbits/sec  690 Mbits/sec  739 Mbits/sec  740 Mbits/sec
# k8s-worker-1  769 Mbits/sec  793 Mbits/sec  798 Mbits/sec  804 Mbits/sec
# k8s-worker-8  758 Mbits/sec          Error          Error          Error
# k8s-worker-5  552 Mbits/sec  533 Mbits/sec  802 Mbits/sec  796 Mbits/sec
# k8s-worker-9              0  734 Mbits/sec  728 Mbits/sec  803 Mbits/sec
# k8s-worker-6  754 Mbits/sec  553 Mbits/sec  442 Mbits/sec  744 Mbits/sec
# k8s-worker-2  775 Mbits/sec              0  805 Mbits/sec  813 Mbits/sec
# k8s-worker-7  803 Mbits/sec  809 Mbits/sec              0  805 Mbits/sec
# k8s-worker-4          Error  623 Mbits/sec  760 Mbits/sec              0
#
#                k8s-worker-3
# k8s-worker-3              0
# k8s-worker-1  796 Mbits/sec
# k8s-worker-8  803 Mbits/sec
# k8s-worker-5          Error
# k8s-worker-9  800 Mbits/sec
# k8s-worker-6  796 Mbits/sec
# k8s-worker-2  764 Mbits/sec
# k8s-worker-7  807 Mbits/sec
# k8s-worker-4  726 Mbits/sec

# %%
# Out:
# Bandwidth from k8s-worker-3 to k8s-worker-1: 806 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-8: 801 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-5: 814 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-9: 813 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-6: 813 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-2: 805 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-7: 815 Mbits/sec
# Bandwidth from k8s-worker-3 to k8s-worker-4: 806 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-3: 806 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-8: 819 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-5: 814 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-9: 819 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-6: 807 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-2: 813 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-1 to k8s-worker-4: 810 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-3: 794 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-1: 813 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-5: 802 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-9: 801 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-6: 796 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-2: 794 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-7: 762 Mbits/sec
# Bandwidth from k8s-worker-8 to k8s-worker-4: 800 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-3: 803 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-1: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-8: 799 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-9: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-6: 806 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-2: 801 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-7: 805 Mbits/sec
# Bandwidth from k8s-worker-5 to k8s-worker-4: 799 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-3: 801 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-1: 813 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-8: 813 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-5: 802 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-6: 810 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-2: 814 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-7: 800 Mbits/sec
# Bandwidth from k8s-worker-9 to k8s-worker-4: 797 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-3: 806 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-1: 804 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-8: 808 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-5: 808 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-9: 804 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-2: 802 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-6 to k8s-worker-4: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-3: 816 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-1: 810 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-8: 815 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-5: 811 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-9: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-6: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-7: 813 Mbits/sec
# Bandwidth from k8s-worker-2 to k8s-worker-4: 816 Mbits/sec
# Bandwidth from k8s-worker-7 to k8s-worker-3: 816 Mbits/sec
# Bandwidth from k8s-worker-7 to k8s-worker-1: 809 Mbits/sec
