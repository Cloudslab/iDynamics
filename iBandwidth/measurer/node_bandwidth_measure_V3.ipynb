# %%
from kubernetes import client, config, stream
import re
import concurrent.futures
import time

# Load Kubernetes configuration
config.load_kube_config()

def measure_bandwidth_from_source_to_target(v1, namespace, source_pod, target_pod, test_duration=5):
    """Measure bandwidth from source pod to target pod."""
    source_name = source_pod.metadata.name
    target_ip = target_pod.status.pod_ip
    target_name = target_pod.metadata.name
    source_node = source_pod.spec.node_name
    target_node = target_pod.spec.node_name

    if source_name == target_name:
        return None  # Skip self-tests

    command = ['iperf3', '-c', target_ip, '-t', str(test_duration)]
    try:
        output = stream.stream(v1.connect_get_namespaced_pod_exec,
                               source_name,
                               namespace,
                               command=command,
                               stderr=True,
                               stdin=False,
                               stdout=True,
                               tty=False)
        # Parse the output for bandwidth
        match = re.search(r'(\d+\.?\d*\s[MKG]bits/sec)', output)
        bandwidth = match.group(1) if match else "Parsing Error"

        # Print the result immediately
        print(f"{source_node} -> {target_node}: {bandwidth}")
        return source_node, target_node, bandwidth

    except Exception as e:
        print(f"Error measuring bandwidth from {source_name} to {target_name}: {e}")
        return source_node, target_node, "Error"

def measure_bandwidth(namespace='measure-nodes-bd', max_concurrent_tasks=3, test_duration=5):
    """Measure bandwidth between all pods in the namespace."""
    v1 = client.CoreV1Api()
    pods = v1.list_namespaced_pod(namespace, label_selector="app=bandwidth-measurement").items

    with concurrent.futures.ThreadPoolExecutor(max_workers=max_concurrent_tasks) as executor:
        futures = [
            executor.submit(measure_bandwidth_from_source_to_target, v1, namespace, src, tgt, test_duration)
            for src in pods for tgt in pods if src.metadata.name != tgt.metadata.name
        ]

        # Collect and print results as they complete
        results = {}
        for future in concurrent.futures.as_completed(futures):
            result = future.result()
            if result:
                src_node, tgt_node, bandwidth = result
                if src_node not in results:
                    results[src_node] = {}
                results[src_node][tgt_node] = bandwidth

    return results

if __name__ == '__main__':
    namespace = 'measure-nodes-bd'
    print("Measuring bandwidth...")
    time.sleep(10)  # Allow some time for the DaemonSet to deploy
    results = measure_bandwidth(namespace=namespace, max_concurrent_tasks= 4, test_duration=10)
    print("\nFinal Cross-Node Bandwidth Results:")
    for src_node, targets in results.items():
        for tgt_node, bandwidth in targets.items():
            print(f"{src_node} -> {tgt_node}: {bandwidth}")
# Out:
# Measuring bandwidth...
# k8s-worker-3 -> k8s-worker-1: 685 Mbits/sec
# k8s-worker-3 -> k8s-worker-9: 711 Mbits/sec
# k8s-worker-3 -> k8s-worker-5: 305 Mbits/sec
# k8s-worker-3 -> k8s-worker-8: 245 Mbits/sec
# k8s-worker-3 -> k8s-worker-6: 439 Mbits/sec
# k8s-worker-3 -> k8s-worker-2: 507 Mbits/sec
# k8s-worker-3 -> k8s-worker-4: 485 Mbits/sec
# k8s-worker-3 -> k8s-worker-7: 342 Mbits/sec
# k8s-worker-1 -> k8s-worker-3: 665 Mbits/sec
# k8s-worker-1 -> k8s-worker-8: 754 Mbits/sec
# k8s-worker-1 -> k8s-worker-9: 667 Mbits/sec
# k8s-worker-1 -> k8s-worker-5: 359 Mbits/sec
# k8s-worker-1 -> k8s-worker-2: 608 Mbits/sec
# k8s-worker-1 -> k8s-worker-6: 560 Mbits/sec
# k8s-worker-1 -> k8s-worker-4: 452 Mbits/sec
# k8s-worker-1 -> k8s-worker-7: 300 Mbits/sec
# k8s-worker-8 -> k8s-worker-3: 442 Mbits/sec
# k8s-worker-8 -> k8s-worker-1: 330 Mbits/sec
# k8s-worker-8 -> k8s-worker-5: 434 Mbits/sec
# k8s-worker-8 -> k8s-worker-9: 411 Mbits/sec
# k8s-worker-8 -> k8s-worker-6: 675 Mbits/sec
# k8s-worker-8 -> k8s-worker-7: 528 Mbits/sec
# k8s-worker-8 -> k8s-worker-4: 548 Mbits/sec
# k8s-worker-8 -> k8s-worker-2: 336 Mbits/sec
# k8s-worker-5 -> k8s-worker-3: 467 Mbits/sec
# k8s-worker-5 -> k8s-worker-8: 484 Mbits/sec
# k8s-worker-5 -> k8s-worker-9: 582 Mbits/sec
# k8s-worker-5 -> k8s-worker-1: 376 Mbits/sec
# k8s-worker-5 -> k8s-worker-6: 302 Mbits/sec
# k8s-worker-5 -> k8s-worker-7: 492 Mbits/sec
# k8s-worker-5 -> k8s-worker-4: 606 Mbits/sec
# k8s-worker-5 -> k8s-worker-2: 397 Mbits/sec
# k8s-worker-9 -> k8s-worker-3: 362 Mbits/sec
# k8s-worker-9 -> k8s-worker-8: 576 Mbits/sec
# k8s-worker-9 -> k8s-worker-1: 619 Mbits/sec
# k8s-worker-9 -> k8s-worker-5: 389 Mbits/sec
# k8s-worker-9 -> k8s-worker-6: 710 Mbits/sec
# k8s-worker-9 -> k8s-worker-7: 736 Mbits/sec
# k8s-worker-9 -> k8s-worker-2: 389 Mbits/sec
# k8s-worker-9 -> k8s-worker-4: 562 Mbits/sec
# k8s-worker-6 -> k8s-worker-1: 679 Mbits/sec
# k8s-worker-6 -> k8s-worker-3: 269 Mbits/sec
# k8s-worker-6 -> k8s-worker-5: 500 Mbits/sec
# k8s-worker-6 -> k8s-worker-8: 243 Mbits/sec
# k8s-worker-6 -> k8s-worker-9: 553 Mbits/sec
# k8s-worker-6 -> k8s-worker-2: 565 Mbits/sec
# k8s-worker-6 -> k8s-worker-7: 422 Mbits/sec
# k8s-worker-6 -> k8s-worker-4: 232 Mbits/sec
# k8s-worker-2 -> k8s-worker-3: 517 Mbits/sec
# k8s-worker-2 -> k8s-worker-8: 620 Mbits/sec
# k8s-worker-2 -> k8s-worker-1: 267 Mbits/sec
# k8s-worker-2 -> k8s-worker-5: 446 Mbits/sec
# k8s-worker-2 -> k8s-worker-6: 419 Mbits/sec
# k8s-worker-2 -> k8s-worker-9: 406 Mbits/sec
# k8s-worker-2 -> k8s-worker-7: 274 Mbits/sec
# k8s-worker-2 -> k8s-worker-4: 294 Mbits/sec
# k8s-worker-7 -> k8s-worker-1: 569 Mbits/sec
# k8s-worker-7 -> k8s-worker-5: 589 Mbits/sec
# k8s-worker-7 -> k8s-worker-3: 259 Mbits/sec
# k8s-worker-7 -> k8s-worker-8: 466 Mbits/sec
# k8s-worker-7 -> k8s-worker-9: 722 Mbits/sec
# k8s-worker-7 -> k8s-worker-4: 545 Mbits/sec
# k8s-worker-7 -> k8s-worker-2: 477 Mbits/sec
# k8s-worker-7 -> k8s-worker-6: 221 Mbits/sec
# k8s-worker-4 -> k8s-worker-8: 598 Mbits/sec
# k8s-worker-4 -> k8s-worker-3: 206 Mbits/sec
# k8s-worker-4 -> k8s-worker-1: 434 Mbits/sec
# k8s-worker-4 -> k8s-worker-5: 682 Mbits/sec
# k8s-worker-4 -> k8s-worker-2: 769 Mbits/sec
# k8s-worker-4 -> k8s-worker-7: 449 Mbits/sec
# k8s-worker-4 -> k8s-worker-6: 242 Mbits/sec
# k8s-worker-4 -> k8s-worker-9: 253 Mbits/sec
#
# Final Cross-Node Bandwidth Results:
# k8s-worker-3 -> k8s-worker-1: 685 Mbits/sec
# k8s-worker-3 -> k8s-worker-9: 711 Mbits/sec
# k8s-worker-3 -> k8s-worker-5: 305 Mbits/sec
# k8s-worker-3 -> k8s-worker-8: 245 Mbits/sec
# k8s-worker-3 -> k8s-worker-6: 439 Mbits/sec
# k8s-worker-3 -> k8s-worker-2: 507 Mbits/sec
# k8s-worker-3 -> k8s-worker-4: 485 Mbits/sec
# k8s-worker-3 -> k8s-worker-7: 342 Mbits/sec
# k8s-worker-1 -> k8s-worker-3: 665 Mbits/sec
# k8s-worker-1 -> k8s-worker-8: 754 Mbits/sec
# k8s-worker-1 -> k8s-worker-9: 667 Mbits/sec
# k8s-worker-1 -> k8s-worker-5: 359 Mbits/sec
# k8s-worker-1 -> k8s-worker-2: 608 Mbits/sec
# k8s-worker-1 -> k8s-worker-6: 560 Mbits/sec
# k8s-worker-1 -> k8s-worker-4: 452 Mbits/sec
# k8s-worker-1 -> k8s-worker-7: 300 Mbits/sec
# k8s-worker-8 -> k8s-worker-3: 442 Mbits/sec
# k8s-worker-8 -> k8s-worker-1: 330 Mbits/sec
# k8s-worker-8 -> k8s-worker-5: 434 Mbits/sec
# k8s-worker-8 -> k8s-worker-9: 411 Mbits/sec
# k8s-worker-8 -> k8s-worker-6: 675 Mbits/sec
# k8s-worker-8 -> k8s-worker-7: 528 Mbits/sec
# k8s-worker-8 -> k8s-worker-4: 548 Mbits/sec
# k8s-worker-8 -> k8s-worker-2: 336 Mbits/sec
# k8s-worker-5 -> k8s-worker-3: 467 Mbits/sec
# k8s-worker-5 -> k8s-worker-8: 484 Mbits/sec
# k8s-worker-5 -> k8s-worker-9: 582 Mbits/sec
# k8s-worker-5 -> k8s-worker-1: 376 Mbits/sec
# k8s-worker-5 -> k8s-worker-6: 302 Mbits/sec
# k8s-worker-5 -> k8s-worker-7: 492 Mbits/sec
# k8s-worker-5 -> k8s-worker-4: 606 Mbits/sec
# k8s-worker-5 -> k8s-worker-2: 397 Mbits/sec
# k8s-worker-9 -> k8s-worker-3: 362 Mbits/sec
# k8s-worker-9 -> k8s-worker-8: 576 Mbits/sec
# k8s-worker-9 -> k8s-worker-1: 619 Mbits/sec
# k8s-worker-9 -> k8s-worker-5: 389 Mbits/sec
# k8s-worker-9 -> k8s-worker-6: 710 Mbits/sec
# k8s-worker-9 -> k8s-worker-7: 736 Mbits/sec
# k8s-worker-9 -> k8s-worker-2: 389 Mbits/sec
# k8s-worker-9 -> k8s-worker-4: 562 Mbits/sec
# k8s-worker-6 -> k8s-worker-1: 679 Mbits/sec
# k8s-worker-6 -> k8s-worker-3: 269 Mbits/sec
# k8s-worker-6 -> k8s-worker-5: 500 Mbits/sec
# k8s-worker-6 -> k8s-worker-8: 243 Mbits/sec
# k8s-worker-6 -> k8s-worker-9: 553 Mbits/sec
# k8s-worker-6 -> k8s-worker-2: 565 Mbits/sec
# k8s-worker-6 -> k8s-worker-7: 422 Mbits/sec
# k8s-worker-6 -> k8s-worker-4: 232 Mbits/sec
# k8s-worker-2 -> k8s-worker-3: 517 Mbits/sec
# k8s-worker-2 -> k8s-worker-8: 620 Mbits/sec
# k8s-worker-2 -> k8s-worker-1: 267 Mbits/sec
# k8s-worker-2 -> k8s-worker-5: 446 Mbits/sec
# k8s-worker-2 -> k8s-worker-6: 419 Mbits/sec
# k8s-worker-2 -> k8s-worker-9: 406 Mbits/sec
# k8s-worker-2 -> k8s-worker-7: 274 Mbits/sec
# k8s-worker-2 -> k8s-worker-4: 294 Mbits/sec
# k8s-worker-7 -> k8s-worker-1: 569 Mbits/sec
# k8s-worker-7 -> k8s-worker-5: 589 Mbits/sec
# k8s-worker-7 -> k8s-worker-3: 259 Mbits/sec
# k8s-worker-7 -> k8s-worker-8: 466 Mbits/sec
# k8s-worker-7 -> k8s-worker-9: 722 Mbits/sec
# k8s-worker-7 -> k8s-worker-4: 545 Mbits/sec
# k8s-worker-7 -> k8s-worker-2: 477 Mbits/sec
# k8s-worker-7 -> k8s-worker-6: 221 Mbits/sec
# k8s-worker-4 -> k8s-worker-8: 598 Mbits/sec
# k8s-worker-4 -> k8s-worker-3: 206 Mbits/sec
# k8s-worker-4 -> k8s-worker-1: 434 Mbits/sec
# k8s-worker-4 -> k8s-worker-5: 682 Mbits/sec
# k8s-worker-4 -> k8s-worker-2: 769 Mbits/sec
# k8s-worker-4 -> k8s-worker-7: 449 Mbits/sec
# k8s-worker-4 -> k8s-worker-6: 242 Mbits/sec
# k8s-worker-4 -> k8s-worker-9: 253 Mbits/sec

# %%
import pandas as pd

# Convert the nested dictionary into a pandas DataFrame
df = pd.DataFrame(results)

# Transpose the DataFrame to align the source and destination workers as per convention
df = df.T

# Fill diagonal with 0's for self-latency (optional, if desired for clarity)
for worker in df.columns:
    df.at[worker, worker] = 0

# Save the DataFrame to a CSV file, and add the date, hour and minute to the file name
import datetime
now = datetime.datetime.now()
filename = f"bandwidth_results_{now.strftime('%Y-%m-%d_%H-%M')}.csv"
df.to_csv("/home/ubuntu/iDynamics/iBandwidth/measurer/data/"+filename)
df
# Out:
#                k8s-worker-1   k8s-worker-9   k8s-worker-5   k8s-worker-8  \
# k8s-worker-3  685 Mbits/sec  711 Mbits/sec  305 Mbits/sec  245 Mbits/sec
# k8s-worker-1              0  667 Mbits/sec  359 Mbits/sec  754 Mbits/sec
# k8s-worker-8  330 Mbits/sec  411 Mbits/sec  434 Mbits/sec              0
# k8s-worker-5  376 Mbits/sec  582 Mbits/sec              0  484 Mbits/sec
# k8s-worker-9  619 Mbits/sec              0  389 Mbits/sec  576 Mbits/sec
# k8s-worker-6  679 Mbits/sec  553 Mbits/sec  500 Mbits/sec  243 Mbits/sec
# k8s-worker-2  267 Mbits/sec  406 Mbits/sec  446 Mbits/sec  620 Mbits/sec
# k8s-worker-7  569 Mbits/sec  722 Mbits/sec  589 Mbits/sec  466 Mbits/sec
# k8s-worker-4  434 Mbits/sec  253 Mbits/sec  682 Mbits/sec  598 Mbits/sec
#
#                k8s-worker-6   k8s-worker-2   k8s-worker-4   k8s-worker-7  \
# k8s-worker-3  439 Mbits/sec  507 Mbits/sec  485 Mbits/sec  342 Mbits/sec
# k8s-worker-1  560 Mbits/sec  608 Mbits/sec  452 Mbits/sec  300 Mbits/sec
# k8s-worker-8  675 Mbits/sec  336 Mbits/sec  548 Mbits/sec  528 Mbits/sec
# k8s-worker-5  302 Mbits/sec  397 Mbits/sec  606 Mbits/sec  492 Mbits/sec
# k8s-worker-9  710 Mbits/sec  389 Mbits/sec  562 Mbits/sec  736 Mbits/sec
# k8s-worker-6              0  565 Mbits/sec  232 Mbits/sec  422 Mbits/sec
# k8s-worker-2  419 Mbits/sec              0  294 Mbits/sec  274 Mbits/sec
# k8s-worker-7  221 Mbits/sec  477 Mbits/sec  545 Mbits/sec              0
# k8s-worker-4  242 Mbits/sec  769 Mbits/sec              0  449 Mbits/sec
#
#                k8s-worker-3
# k8s-worker-3              0
# k8s-worker-1  665 Mbits/sec
# k8s-worker-8  442 Mbits/sec
# k8s-worker-5  467 Mbits/sec
# k8s-worker-9  362 Mbits/sec
# k8s-worker-6  269 Mbits/sec
# k8s-worker-2  517 Mbits/sec
# k8s-worker-7  259 Mbits/sec
# k8s-worker-4  206 Mbits/sec
