# %%
# using wrk tool to run the four differnt test workloads (request A, request B, request C, request_mix ABC) for Social Network Application in name space of "social-network"
# this test is used to observe the different performace of the Social Network Application under different workloads(requests). Each type of request is running 5 mins

import os
import subprocess

# Define the parameters
thread_num = 4
connections = 100
duration = '2m'

# QPS = [50, 200, 400]
QPS = [20]

request_A_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/compose-post.lua"
request_B_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-home-timeline.lua"
request_C_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-user-timeline.lua"

request_mix_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/mixed-workload.lua" # default mix percentage: 60% A, 30% B, 10% C

script_path = [
    request_A_script_path,
    request_B_script_path,
    request_C_script_path,
    request_mix_script_path
]

url = [
    #diffferent namespace of social-network Application
    "http://nginx-thrift.social-network.svc.cluster.local:8080"       # in namespace of "social-network"
#     "http://nginx-thrift.social-network2.svc.cluster.local:8080",
#    "http://nginx-thrift.social-network3.svc.cluster.local:8080"
]


# Define the output file path in the current directory and file name with the format of current time (Year_MONTH_Day_Hour_Minute)

output_file = os.path.join(os.getcwd(), "/home/ubuntu/iDynamics/Evaluations/Policy1_eval_Graph_dynamics/output_result1.txt")

# Ensure the output file is empty at the start
with open(output_file, 'w') as f:
    f.write("")

for i in range(len(url)):
    for script in script_path:
        command = [
            "/home/ubuntu/DeathStarBench/wrk2/wrk",
            "-D", "exp",
            f"-t{thread_num}",
            f"-c{connections}",
            f"-d{duration}",
            "-L",
            "-s", script,
            url[i],
            f"-R{QPS[0]}"
        ]
        print(f"Running command: {' '.join(command)}")
        
        # make sure each loop runs one command, after finish current loop, run the next command
        # run the command
        process = subprocess.Popen(command, stdout=subprocess.PIPE)
        output, error = process.communicate()
        output = output.decode("utf-8")
        print(output)
        # Write the output to the output file
        with open(output_file, 'a') as f:
            f.write(output)
            f.write("\n\n")
        print(f"Finished running command: {' '.join(command)}")
        print("--------------------------------------------------")
print("All tests are done!")
# Out:
# Running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/compose-post.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# Running 2m test @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   4 threads and 100 connections
#
#   Thread calibration: mean lat.: 303.042ms, rate sampling interval: 990ms
#   Thread calibration: mean lat.: 280.451ms, rate sampling interval: 638ms
#   Thread calibration: mean lat.: 278.194ms, rate sampling interval: 767ms
#   Thread calibration: mean lat.: 314.308ms, rate sampling interval: 969ms
#
# -----------------------------------------------------------------------
# Test Results @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   Thread Stats   Avg      Stdev     99%   +/- Stdev
#     Latency   246.85ms   33.72ms 422.40ms   90.49%
#     Req/Sec     4.67      2.47    11.00     81.82%
#   Latency Distribution (HdrHistogram - Recorded Latency)
#  50.000%  235.52ms
#  75.000%  238.21ms
#  90.000%  278.27ms
#  99.000%  422.40ms
#  99.900%  517.38ms
#  99.990%  546.30ms
#  99.999%  546.30ms
# 100.000%  546.30ms
#
#   Detailed Percentile spectrum:
#        Value   Percentile   TotalCount 1/(1-Percentile)
#
#      185.343     0.000000            1         1.00
#      233.087     0.100000          222         1.11
#      233.855     0.200000          446         1.25
#      234.495     0.300000          680         1.43
#      235.007     0.400000          888         1.67
#      235.519     0.500000         1109         2.00
#      235.903     0.550000         1234         2.22
#      236.287     0.600000         1350         2.50
#      236.671     0.650000         1445         2.86
#      237.311     0.700000         1563         3.33
#      238.207     0.750000         1651         4.00
#      240.511     0.775000         1704         4.44
#      244.991     0.800000         1759         5.00
#      250.495     0.825000         1814         5.71
#      256.895     0.850000         1870         6.67
#      273.407     0.875000         1926         8.00
#      274.943     0.887500         1951         8.89
#      278.527     0.900000         1981        10.00
#      283.391     0.912500         2006        11.43
#      286.463     0.925000         2036        13.33
#      289.791     0.937500         2061        16.00
#      292.351     0.943750         2075        17.78
#      295.423     0.950000         2089        20.00
#      303.615     0.956250         2102        22.86
#      312.575     0.962500         2116        26.67
#      322.559     0.968750         2130        32.00
#      327.423     0.971875         2137        35.56
#      338.687     0.975000         2144        40.00
#      351.743     0.978125         2150        45.71
#      374.783     0.981250         2157        53.33
#      391.679     0.984375         2164        64.00
#      406.271     0.985938         2168        71.11
#      413.695     0.987500         2171        80.00
#      418.815     0.989062         2175        91.43
#      434.431     0.990625         2178       106.67
#      445.439     0.992188         2181       128.00
#      448.255     0.992969         2183       142.22
#      450.559     0.993750         2185       160.00
#      454.911     0.994531         2186       182.86
#      459.519     0.995313         2188       213.33
#      464.639     0.996094         2190       256.00
#      484.095     0.996484         2191       284.44
#      488.959     0.996875         2192       320.00
#      488.959     0.997266         2192       365.71
#      493.567     0.997656         2193       426.67
#      499.967     0.998047         2194       512.00
#      509.951     0.998242         2195       568.89
#      509.951     0.998437         2195       640.00
#      509.951     0.998633         2195       731.43
#      517.375     0.998828         2196       853.33
#      517.375     0.999023         2196      1024.00
#      535.039     0.999121         2197      1137.78
#      535.039     0.999219         2197      1280.00
#      535.039     0.999316         2197      1462.86
#      535.039     0.999414         2197      1706.67
#      535.039     0.999512         2197      2048.00
#      546.303     0.999561         2198      2275.56
#      546.303     1.000000         2198          inf
# #[Mean    =      246.851, StdDeviation   =       33.721]
# #[Max     =      545.792, Total count    =         2198]
# #[Buckets =           27, SubBuckets     =         2048]
# -----------------------------------------------------------------------
#   2401 requests in 2.00m, 703.80KB read
#   Socket errors: connect 0, read 0, write 0, timeout 3995
#   Non-2xx or 3xx responses: 9
# Requests/sec:     20.00
# Transfer/sec:      5.86KB
#
# Finished running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/compose-post.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# --------------------------------------------------
# Running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-home-timeline.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# Running 2m test @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   4 threads and 100 connections
#
#   Thread calibration: mean lat.: 56.532ms, rate sampling interval: 113ms
#   Thread calibration: mean lat.: 67.344ms, rate sampling interval: 167ms
#   Thread calibration: mean lat.: 59.608ms, rate sampling interval: 113ms
#   Thread calibration: mean lat.: 67.389ms, rate sampling interval: 195ms
#
# -----------------------------------------------------------------------
# Test Results @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   Thread Stats   Avg      Stdev     99%   +/- Stdev
#     Latency    56.99ms    8.34ms 106.69ms   97.08%
#     Req/Sec     4.68      5.83    26.00     89.13%
#   Latency Distribution (HdrHistogram - Recorded Latency)
#  50.000%   55.58ms
#  75.000%   56.13ms
#  90.000%   56.70ms
#  99.000%  106.69ms
#  99.900%  134.40ms
#  99.990%  135.29ms
#  99.999%  135.29ms
# 100.000%  135.29ms
#
#   Detailed Percentile spectrum:
#        Value   Percentile   TotalCount 1/(1-Percentile)
#
#       53.791     0.000000            1         1.00
#       54.751     0.100000          242         1.11
#       55.007     0.200000          451         1.25
#       55.199     0.300000          681         1.43
#       55.391     0.400000          884         1.67
#       55.583     0.500000         1127         2.00
#       55.647     0.550000         1208         2.22
#       55.775     0.600000         1338         2.50
#       55.871     0.650000         1431         2.86
#       55.999     0.700000         1552         3.33
#       56.127     0.750000         1661         4.00
#       56.191     0.775000         1713         4.44
#       56.255     0.800000         1765         5.00
#       56.351     0.825000         1821         5.71
#       56.447     0.850000         1873         6.67
#       56.543     0.875000         1921         8.00
#       56.639     0.887500         1961         8.89
#       56.703     0.900000         1981        10.00
#       56.767     0.912500         2006        11.43
#       56.863     0.925000         2035        13.33
#       56.991     0.937500         2060        16.00
#       57.087     0.943750         2074        17.78
#       57.215     0.950000         2088        20.00
#       57.407     0.956250         2099        22.86
#       58.111     0.962500         2112        26.67
#       61.311     0.968750         2126        32.00
#       78.911     0.971875         2133        35.56
#       92.991     0.975000         2140        40.00
#       95.871     0.978125         2147        45.71
#       98.431     0.981250         2153        53.33
#      101.375     0.984375         2160        64.00
#      104.831     0.985938         2164        71.11
#      105.279     0.987500         2167        80.00
#      106.559     0.989062         2171        91.43
#      107.839     0.990625         2174       106.67
#      108.351     0.992188         2177       128.00
#      111.423     0.992969         2179       142.22
#      112.191     0.993750         2181       160.00
#      112.511     0.994531         2184       182.86
#      112.511     0.995313         2184       213.33
#      113.279     0.996094         2186       256.00
#      113.407     0.996484         2187       284.44
#      114.175     0.996875         2188       320.00
#      115.327     0.997266         2189       365.71
#      115.327     0.997656         2189       426.67
#      129.023     0.998047         2190       512.00
#      133.887     0.998242         2191       568.89
#      133.887     0.998437         2191       640.00
#      134.399     0.998633         2192       731.43
#      134.399     0.998828         2192       853.33
#      134.399     0.999023         2192      1024.00
#      134.655     0.999121         2193      1137.78
#      134.655     0.999219         2193      1280.00
#      134.655     0.999316         2193      1462.86
#      134.655     0.999414         2193      1706.67
#      134.655     0.999512         2193      2048.00
#      135.295     0.999561         2194      2275.56
#      135.295     1.000000         2194          inf
# #[Mean    =       56.994, StdDeviation   =        8.340]
# #[Max     =      135.168, Total count    =         2194]
# #[Buckets =           27, SubBuckets     =         2048]
# -----------------------------------------------------------------------
#   2409 requests in 2.00m, 665.94KB read
#   Socket errors: connect 0, read 0, write 0, timeout 3976
#   Non-2xx or 3xx responses: 2
# Requests/sec:     20.07
# Transfer/sec:      5.55KB
#
# Finished running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-home-timeline.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# --------------------------------------------------
# Running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-user-timeline.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# Running 2m test @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   4 threads and 100 connections
#
#   Thread calibration: mean lat.: 181.316ms, rate sampling interval: 410ms
#   Thread calibration: mean lat.: 187.634ms, rate sampling interval: 474ms
#   Thread calibration: mean lat.: 191.402ms, rate sampling interval: 470ms
#   Thread calibration: mean lat.: 184.865ms, rate sampling interval: 464ms
#
# -----------------------------------------------------------------------
# Test Results @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   Thread Stats   Avg      Stdev     99%   +/- Stdev
#     Latency   180.24ms   34.49ms 319.74ms   85.23%
#     Req/Sec     4.63      3.16    14.00     79.26%
#   Latency Distribution (HdrHistogram - Recorded Latency)
#  50.000%  175.62ms
#  75.000%  187.13ms
#  90.000%  205.44ms
#  99.000%  319.74ms
#  99.900%  379.14ms
#  99.990%  486.65ms
#  99.999%  486.65ms
# 100.000%  486.65ms
#
#   Detailed Percentile spectrum:
#        Value   Percentile   TotalCount 1/(1-Percentile)
#
#       79.487     0.000000            1         1.00
#      155.647     0.100000          221         1.11
#      163.199     0.200000          456         1.25
#      164.607     0.300000          662         1.43
#      167.807     0.400000          880         1.67
#      175.615     0.500000         1107         2.00
#      176.511     0.550000         1213         2.22
#      177.919     0.600000         1317         2.50
#      180.351     0.650000         1427         2.86
#      185.343     0.700000         1537         3.33
#      187.135     0.750000         1650         4.00
#      187.903     0.775000         1706         4.44
#      188.799     0.800000         1761         5.00
#      191.103     0.825000         1811         5.71
#      202.239     0.850000         1865         6.67
#      204.031     0.875000         1920         8.00
#      204.671     0.887500         1952         8.89
#      205.439     0.900000         1978        10.00
#      211.327     0.912500         2003        11.43
#      224.383     0.925000         2030        13.33
#      238.207     0.937500         2057        16.00
#      243.327     0.943750         2071        17.78
#      249.471     0.950000         2085        20.00
#      261.119     0.956250         2099        22.86
#      269.567     0.962500         2113        26.67
#      276.479     0.968750         2126        32.00
#      282.367     0.971875         2133        35.56
#      286.463     0.975000         2140        40.00
#      291.327     0.978125         2147        45.71
#      295.423     0.981250         2153        53.33
#      303.615     0.984375         2160        64.00
#      307.199     0.985938         2164        71.11
#      310.783     0.987500         2167        80.00
#      319.743     0.989062         2172        91.43
#      323.583     0.990625         2174       106.67
#      327.679     0.992188         2177       128.00
#      328.959     0.992969         2179       142.22
#      333.567     0.993750         2181       160.00
#      333.823     0.994531         2183       182.86
#      336.639     0.995313         2185       213.33
#      339.199     0.996094         2186       256.00
#      340.479     0.996484         2188       284.44
#      340.479     0.996875         2188       320.00
#      348.671     0.997266         2189       365.71
#      348.671     0.997656         2189       426.67
#      349.695     0.998047         2190       512.00
#      373.503     0.998242         2191       568.89
#      373.503     0.998437         2191       640.00
#      379.135     0.998633         2192       731.43
#      379.135     0.998828         2192       853.33
#      379.135     0.999023         2192      1024.00
#      438.015     0.999121         2193      1137.78
#      438.015     0.999219         2193      1280.00
#      438.015     0.999316         2193      1462.86
#      438.015     0.999414         2193      1706.67
#      438.015     0.999512         2193      2048.00
#      486.655     0.999561         2194      2275.56
#      486.655     1.000000         2194          inf
# #[Mean    =      180.245, StdDeviation   =       34.486]
# #[Max     =      486.400, Total count    =         2194]
# #[Buckets =           27, SubBuckets     =         2048]
# -----------------------------------------------------------------------
#   2406 requests in 2.00m, 1.98MB read
#   Socket errors: connect 0, read 0, write 0, timeout 3988
#   Non-2xx or 3xx responses: 2308
# Requests/sec:     20.04
# Transfer/sec:     16.88KB
#
# Finished running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-user-timeline.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# --------------------------------------------------
# Running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/mixed-workload.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# Running 2m test @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   4 threads and 100 connections
#
#   Thread calibration: mean lat.: 122.594ms, rate sampling interval: 407ms
#   Thread calibration: mean lat.: 134.654ms, rate sampling interval: 557ms
#   Thread calibration: mean lat.: 132.779ms, rate sampling interval: 569ms
#   Thread calibration: mean lat.: 134.569ms, rate sampling interval: 576ms
#
# -----------------------------------------------------------------------
# Test Results @ http://nginx-thrift.social-network.svc.cluster.local:8080
#   Thread Stats   Avg      Stdev     99%   +/- Stdev
#     Latency   119.32ms   86.35ms 368.89ms   86.87%
#     Req/Sec     4.50      2.98    12.00     82.24%
#   Latency Distribution (HdrHistogram - Recorded Latency)
#  50.000%   56.22ms
#  75.000%  177.28ms
#  90.000%  277.25ms
#  99.000%  368.89ms
#  99.900%  471.55ms
#  99.990%  540.16ms
#  99.999%  540.16ms
# 100.000%  540.16ms
#
#   Detailed Percentile spectrum:
#        Value   Percentile   TotalCount 1/(1-Percentile)
#
#       54.015     0.000000            2         1.00
#       54.943     0.100000          221         1.11
#       55.231     0.200000          443         1.25
#       55.551     0.300000          675         1.43
#       55.807     0.400000          887         1.67
#       56.223     0.500000         1105         2.00
#       56.735     0.550000         1211         2.22
#      113.407     0.600000         1316         2.50
#      164.095     0.650000         1428         2.86
#      166.783     0.700000         1536         3.33
#      177.279     0.750000         1645         4.00
#      179.455     0.775000         1700         4.44
#      183.679     0.800000         1756         5.00
#      188.671     0.825000         1811         5.71
#      192.511     0.850000         1865         6.67
#      210.687     0.875000         1919         8.00
#      245.887     0.887500         1947         8.89
#      277.247     0.900000         1976        10.00
#      282.111     0.912500         2002        11.43
#      287.999     0.925000         2032        13.33
#      289.023     0.937500         2056        16.00
#      289.791     0.943750         2074        17.78
#      290.303     0.950000         2086        20.00
#      291.839     0.956250         2098        22.86
#      296.447     0.962500         2111        26.67
#      300.031     0.968750         2125        32.00
#      307.967     0.971875         2132        35.56
#      312.831     0.975000         2139        40.00
#      321.023     0.978125         2146        45.71
#      327.679     0.981250         2152        53.33
#      340.479     0.984375         2159        64.00
#      345.599     0.985938         2164        71.11
#      352.255     0.987500         2166        80.00
#      362.239     0.989062         2170        91.43
#      376.831     0.990625         2173       106.67
#      388.351     0.992188         2176       128.00
#      393.727     0.992969         2178       142.22
#      398.079     0.993750         2180       160.00
#      398.847     0.994531         2182       182.86
#      406.783     0.995313         2183       213.33
#      412.671     0.996094         2185       256.00
#      419.327     0.996484         2186       284.44
#      425.983     0.996875         2187       320.00
#      444.671     0.997266         2188       365.71
#      444.671     0.997656         2188       426.67
#      454.911     0.998047         2189       512.00
#      468.991     0.998242         2190       568.89
#      468.991     0.998437         2190       640.00
#      471.551     0.998633         2191       731.43
#      471.551     0.998828         2191       853.33
#      471.551     0.999023         2191      1024.00
#      486.655     0.999121         2192      1137.78
#      486.655     0.999219         2192      1280.00
#      486.655     0.999316         2192      1462.86
#      486.655     0.999414         2192      1706.67
#      486.655     0.999512         2192      2048.00
#      540.159     0.999561         2193      2275.56
#      540.159     1.000000         2193          inf
# #[Mean    =      119.323, StdDeviation   =       86.349]
# #[Max     =      539.648, Total count    =         2193]
# #[Buckets =           27, SubBuckets     =         2048]
# -----------------------------------------------------------------------
#   2408 requests in 2.00m, 1.07MB read
#   Socket errors: connect 0, read 0, write 0, timeout 3972
#   Non-2xx or 3xx responses: 686
# Requests/sec:     20.06
# Transfer/sec:      9.11KB
#
# Finished running command: /home/ubuntu/DeathStarBench/wrk2/wrk -D exp -t4 -c100 -d2m -L -s /home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/mixed-workload.lua http://nginx-thrift.social-network.svc.cluster.local:8080 -R20
# --------------------------------------------------
# All tests are done!
