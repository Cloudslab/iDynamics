# %%
# from Policy1_demo_workloads import wrk_different_requests
# from iDynamicsPackagesModules.SchedulingPolicyExtender.my_cluster_utils import (
#     gather_all_nodes, build_nodeinfo_objects,
#     build_podinfo_objects, gather_all_pods)

# from iDynamicsPackagesModules.GraphDynamicsAnalyzer.graph_builder import build_call_graph
from iDynamicsPackagesModules.Evaluations.Policy1_eval_Graph_dynamics.Policy1_Call_Graph_Aware import Policy1CallGraphAware
# from iDynamicsPackagesModules.Evaluations.Policy2_eval_Delay_dynamics.Policy2_Latency_Aware import Policy2LatencyAware
# from iDynamicsPackagesModules.Evaluations.Policy3_eval_Bandwidth_dynamics.Policy3_Bandwidth_Aware import Policy3BandwidthAware

# from Policy1_demo_workloads import run_workload_varing_callGraph
# Out:
# Pods already exist in the namespace. Skipping DaemonSet deployment.

# %%
import time
import threading


def evaluate_policy1_scheudlder():
    # Initialize the scheduler with necessary parameters
    app1_prom_url = "http://10.105.116.175:9090"
    app1_qos_target = 150  # QoS target in milliseconds
    # time_window is the look_back window for the average response time
    app1_time_window = 1  # Time window in minutes,
    app1_namespace = 'social-network'
    app1_response_code = '200'  # HTTP response code to consider

    # Create an instance of the scheduler
    policy1 = Policy1CallGraphAware()
    policy1.initialize_policy(dynamics_config={"traffic_pairs": {}}, prom_url=app1_prom_url, 
                            qos_target = app1_qos_target, time_window = app1_time_window, 
                            namespace = app1_namespace, response_code = app1_response_code)

    # Run the scheduler
    while True:
        policy1.run()
        time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds

time.sleep(60*16*2 + 60*3)
evaluate_policy1_scheudlder()

# (1) before running the Policy1 scheduler, we run the workload for the first time 
# to obtain performance in default k8s scheduler

# run_workload_varing_callGraph(each_wrk2_duration='3m') # eg., "30s", "1m", 5m", "10m", "15m"
#sleep for 2 mins
# time.sleep(180)

# (2) Conccurently run evaluate_policy1_scheudlder() and run_workload_varing_callGraph()
# workload_thread = threading.Thread(target = run_workload_varing_callGraph, kwargs={'each_wrk2_duration':'3m'})
# scheduler_thread = threading.Thread(target=evaluate_policy1_scheudlder)
# workload_thread.start()
# scheduler_thread.start()

# # Wait for both threads to finish
# workload_thread.join()
# scheduler_thread.join()
# Out:
# Average response time = 12.21 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.23 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.83 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.65 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.55 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.83 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 13.28 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 13.31 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.90 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 13.78 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 14.32 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 13.43 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.10 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.21 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.27 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.16 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.24 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.37 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.34 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.27 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.19 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.30 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 12.18 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 16.36 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 30.15 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 45.25 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 64.60 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 93.33 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 132.22 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 167.82 ms
# Trigger = True
# Ready Deployments: ['compose-post-service', 'home-timeline-redis', 'home-timeline-service', 'jaeger', 'media-frontend', 'media-memcached', 'media-mongodb', 'media-service', 'nginx-thrift', 'post-storage-memcached', 'post-storage-mongodb', 'post-storage-service', 'social-graph-mongodb', 'social-graph-redis', 'social-graph-service', 'text-service', 'unique-id-service', 'url-shorten-memcached', 'url-shorten-mongodb', 'url-shorten-service', 'user-memcached', 'user-mention-service', 'user-mongodb', 'user-service', 'user-timeline-mongodb', 'user-timeline-redis', 'user-timeline-service']
# from compose-post-service to home-timeline-service ~ 29.1 KB
# from compose-post-service to media-service ~ 41.2 KB
# from compose-post-service to post-storage-service ~ 157.4 KB
# from compose-post-service to text-service ~ 220.4 KB
# from compose-post-service to unique-id-service ~ 25.0 KB
# from compose-post-service to user-service ~ 34.6 KB
# from compose-post-service to user-timeline-service ~ 27.6 KB
# from home-timeline-service to home-timeline-redis ~ 39.3 KB
# from home-timeline-service to post-storage-service ~ 132.3 KB
# from home-timeline-service to social-graph-service ~ 26.1 KB
# from nginx-thrift to compose-post-service ~ 124.0 KB
# from nginx-thrift to home-timeline-service ~ 157.4 KB
# from nginx-thrift to user-timeline-service ~ 0.0 KB
# from post-storage-service to post-storage-memcached ~ 0.0 KB
# from post-storage-service to post-storage-mongodb ~ 216.9 KB
# from social-graph-service to social-graph-mongodb ~ 38.9 KB
# from social-graph-service to social-graph-redis ~ 8.3 KB
# from text-service to url-shorten-service ~ 124.6 KB
# from text-service to user-mention-service ~ 36.3 KB
# from url-shorten-service to url-shorten-mongodb ~ 113.6 KB
# from user-mention-service to user-memcached ~ 39.5 KB
# from user-mention-service to user-mongodb ~ 47.8 KB
# from user-service to user-mongodb ~ 1.0 KB
# from user-timeline-service to post-storage-service ~ 0.0 KB
# from user-timeline-service to user-timeline-mongodb ~ 229.1 KB
# from user-timeline-service to user-timeline-redis ~ 13.7 KB
# [Policy1CallGraphAware] Updated traffic matrix for app in namespace social-network with 23 edges.
# === Scenario1: Call-Graph_Aware ===
#  Pod user-timeline-service-6c7b9c48bc-rmvmh -> schedule to Node k8s-worker-1
#  Pod user-timeline-mongodb-865c9c4975-fpv8v -> schedule to Node k8s-worker-1
#  Pod compose-post-service-79fffc8f65-ql7hj -> schedule to Node k8s-worker-1
#  Pod text-service-84d48878-zvqhn -> schedule to Node k8s-worker-1
#  Pod post-storage-service-696b99f894-nzw7g -> schedule to Node k8s-worker-1
#  Pod post-storage-mongodb-6cd66b64db-xfdws -> schedule to Node k8s-worker-1
#  Pod home-timeline-service-5847cc645f-n55x7 -> schedule to Node k8s-worker-1
#  Pod url-shorten-service-8487489949-sjslc -> schedule to Node k8s-worker-1
#  Pod url-shorten-mongodb-5d6779b787-6xclp -> schedule to Node k8s-worker-1
#  Pod user-mention-service-6f9554bdfd-25ksb -> schedule to Node k8s-worker-1
#  Pod user-mongodb-54f7856897-lbh9c -> schedule to Node k8s-worker-1
#  Pod social-graph-service-7f767545d4-4tsx2 -> schedule to Node k8s-worker-1
#  Pod social-graph-mongodb-7db6d5b58-f7h7h -> schedule to Node k8s-worker-1
#  Pod home-timeline-redis-74777776d8-tgdmv -> schedule to Node k8s-worker-2
#  Pod unique-id-service-78db644977-8sdtw -> schedule to Node k8s-worker-2
#  Pod url-shorten-memcached-645954f675-6h55r -> schedule to Node k8s-worker-3
#  Pod media-frontend-6f8b6db9bb-9jw8m -> schedule to Node k8s-worker-4
#  Pod user-memcached-8474bbc969-fsccv -> schedule to Node k8s-worker-4
#  Pod media-memcached-5584c4bbdf-jbnxw -> schedule to Node k8s-worker-5
#  Pod user-service-64b5d876b-l7ssn -> schedule to Node k8s-worker-5
#  Pod media-mongodb-6fd7768d66-5b59g -> schedule to Node k8s-worker-6
#  Pod user-timeline-redis-75647777b4-xl9wz -> schedule to Node k8s-worker-6
#  Pod media-service-7fbfc5f4c-r2nxq -> schedule to Node k8s-worker-7
#  Pod post-storage-memcached-786b6455f-flqjx -> schedule to Node k8s-worker-8
#  Pod social-graph-redis-6b4dcf589-fkj8m -> schedule to Node k8s-worker-9
# Starting migration of user-timeline-service to k8s-worker-1
# Starting migration of user-timeline-mongodb to k8s-worker-1
# Starting migration of compose-post-service to k8s-worker-1
# Starting migration of text-service to k8s-worker-1
# Starting migration of post-storage-service to k8s-worker-1
# Starting migration of post-storage-mongodb to k8s-worker-1
# Starting migration of home-timeline-service to k8s-worker-1
# Starting migration of url-shorten-service to k8s-worker-1
# Starting migration of url-shorten-mongodb to k8s-worker-1
# Starting migration of user-mention-service to k8s-worker-1
# Starting migration of user-mongodb to k8s-worker-1
# Starting migration of social-graph-service to k8s-worker-1
# Starting migration of social-graph-mongodb to k8s-worker-1
# Starting migration of home-timeline-redis to k8s-worker-2
# Starting migration of unique-id-service to k8s-worker-2
# Starting migration of url-shorten-memcached to k8s-worker-3
# Deployment 'compose-post-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-frontend to k8s-worker-4
# Deployment 'user-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'text-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-mention-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of user-memcached to k8s-worker-4
# Deployment 'url-shorten-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-memcached to k8s-worker-5
# Deployment 'url-shorten-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'unique-id-service' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Starting migration of user-service to k8s-worker-5
# Deployment 'user-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-mongodb to k8s-worker-6
# Starting migration of user-timeline-redis to k8s-worker-6
# Starting migration of media-service to k8s-worker-7
# Starting migration of post-storage-memcached to k8s-worker-8
# Starting migration of social-graph-redis to k8s-worker-9
# Deployment 'url-shorten-memcached' patched to schedule pods on 'k8s-worker-3'.
# Waiting for the rolling update to complete...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# Deployment 'media-memcached' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-redis' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Deployment 'user-memcached' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'media-frontend' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-redis' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'user-service' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'media-mongodb' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-memcached' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-redis' patched to schedule pods on 'k8s-worker-9'.
# Waiting for the rolling update to complete...
# Deployment 'media-service' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 2
# All pods are running on the new node.
# Microservice text-service migrated successfully to k8s-worker-1.
# Migration result: Migration of text-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 2
# All pods are running on the new node.
# Microservice url-shorten-service migrated successfully to k8s-worker-1.
# Migration result: Migration of url-shorten-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 2
# All pods are running on the new node.
# Microservice user-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 2
# All pods are running on the new node.
# Microservice compose-post-service migrated successfully to k8s-worker-1.
# Migration result: Migration of compose-post-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of url-shorten-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-memcached migrated successfully to k8s-worker-4.
# Migration result: Migration of user-memcached to k8s-worker-4 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-mongodb migrated successfully to k8s-worker-6.
# Migration result: Migration of media-mongodb to k8s-worker-6 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-redis migrated successfully to k8s-worker-6.
# Migration result: Migration of user-timeline-redis to k8s-worker-6 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-redis migrated successfully to k8s-worker-9.
# Migration result: Migration of social-graph-redis to k8s-worker-9 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-memcached migrated successfully to k8s-worker-3.
# Migration result: Migration of url-shorten-memcached to k8s-worker-3 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-redis migrated successfully to k8s-worker-2.
# Migration result: Migration of home-timeline-redis to k8s-worker-2 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-memcached migrated successfully to k8s-worker-5.
# Migration result: Migration of media-memcached to k8s-worker-5 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-memcached migrated successfully to k8s-worker-8.
# Migration result: Migration of post-storage-memcached to k8s-worker-8 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-frontend migrated successfully to k8s-worker-4.
# Migration result: Migration of media-frontend to k8s-worker-4 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated=all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
#  False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mention-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mention-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-service migrated successfully to k8s-worker-7.
# Migration result: Migration of media-service to k8s-worker-7 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-service migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of home-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice unique-id-service migrated successfully to k8s-worker-2.
# Migration result: Migration of unique-id-service to k8s-worker-2 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-service migrated successfully to k8s-worker-5.
# Migration result: Migration of user-service to k8s-worker-5 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-service migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-service to k8s-worker-1 completed.
# Average response time = 150.16 ms
# Trigger = True
# Ready Deployments: ['compose-post-service', 'home-timeline-redis', 'home-timeline-service', 'jaeger', 'media-frontend', 'media-memcached', 'media-mongodb', 'media-service', 'nginx-thrift', 'post-storage-memcached', 'post-storage-mongodb', 'post-storage-service', 'social-graph-mongodb', 'social-graph-redis', 'social-graph-service', 'text-service', 'unique-id-service', 'url-shorten-memcached', 'url-shorten-mongodb', 'url-shorten-service', 'user-memcached', 'user-mention-service', 'user-mongodb', 'user-service', 'user-timeline-mongodb', 'user-timeline-redis', 'user-timeline-service']
# from compose-post-service to home-timeline-service ~ 35.5 KB
# from compose-post-service to media-service ~ 50.5 KB
# from compose-post-service to post-storage-service ~ 194.4 KB
# from compose-post-service to text-service ~ 268.7 KB
# from compose-post-service to unique-id-service ~ 30.9 KB
# from compose-post-service to user-service ~ 42.2 KB
# from compose-post-service to user-timeline-service ~ 34.1 KB
# from home-timeline-service to home-timeline-redis ~ 41.3 KB
# from home-timeline-service to post-storage-service ~ 139.4 KB
# from home-timeline-service to social-graph-service ~ 21.0 KB
# from nginx-thrift to compose-post-service ~ 151.8 KB
# from nginx-thrift to home-timeline-service ~ 135.4 KB
# from nginx-thrift to user-timeline-service ~ 0.0 KB
# from post-storage-service to post-storage-memcached ~ 0.0 KB
# from post-storage-service to post-storage-mongodb ~ 177.7 KB
# from social-graph-service to social-graph-mongodb ~ 0.0 KB
# from social-graph-service to social-graph-redis ~ 0.0 KB
# from text-service to url-shorten-service ~ 105.2 KB
# from text-service to user-mention-service ~ 29.4 KB
# from url-shorten-service to url-shorten-mongodb ~ 92.4 KB
# from user-mention-service to user-memcached ~ 31.1 KB
# from user-mention-service to user-mongodb ~ 0.0 KB
# from user-service to user-mongodb ~ 0.0 KB
# from user-timeline-service to post-storage-service ~ 0.0 KB
# from user-timeline-service to user-timeline-mongodb ~ 61.7 KB
# from user-timeline-service to user-timeline-redis ~ 11.0 KB
# [Policy1CallGraphAware] Updated traffic matrix for app in namespace social-network with 19 edges.
# === Scenario1: Call-Graph_Aware ===
#  Pod compose-post-service-5577db79f5-t5kfg -> schedule to Node k8s-worker-1
#  Pod text-service-7fc68b959d-2hchv -> schedule to Node k8s-worker-1
#  Pod post-storage-service-665799f78d-k8bsn -> schedule to Node k8s-worker-1
#  Pod post-storage-mongodb-77f68cd446-dhmsg -> schedule to Node k8s-worker-1
#  Pod home-timeline-service-765d6df88f-r4m86 -> schedule to Node k8s-worker-1
#  Pod url-shorten-service-8849d875-mbgnl -> schedule to Node k8s-worker-1
#  Pod url-shorten-mongodb-df8f5b5c9-8mv48 -> schedule to Node k8s-worker-1
#  Pod user-timeline-service-69b9bf6d6f-bg7hk -> schedule to Node k8s-worker-1
#  Pod user-timeline-mongodb-569fc84d55-f5lwm -> schedule to Node k8s-worker-1
#  Pod user-mention-service-954dbd6f6-spgrn -> schedule to Node k8s-worker-1
#  Pod user-memcached-785f4844f8-6zwdm -> schedule to Node k8s-worker-1
#  Pod home-timeline-redis-5b66669785-4kscg -> schedule to Node k8s-worker-2
#  Pod social-graph-redis-7c9c8db9d5-crnfp -> schedule to Node k8s-worker-2
#  Pod social-graph-service-695bd7747d-mkrsp -> schedule to Node k8s-worker-3
#  Pod media-frontend-f9d45f8c9-z5bfd -> schedule to Node k8s-worker-4
#  Pod unique-id-service-78bcf54fdb-z9nh8 -> schedule to Node k8s-worker-4
#  Pod media-memcached-5b8b4b94c7-q75x6 -> schedule to Node k8s-worker-5
#  Pod url-shorten-memcached-69f9c56b67-lbgwj -> schedule to Node k8s-worker-5
#  Pod media-mongodb-78b59c496c-zrm5n -> schedule to Node k8s-worker-6
#  Pod user-mongodb-5b44c784c7-pnt58 -> schedule to Node k8s-worker-6
#  Pod media-service-cbcdcbfb9-rxdlr -> schedule to Node k8s-worker-7
#  Pod user-service-f84b7b56b-jmnv4 -> schedule to Node k8s-worker-7
#  Pod post-storage-memcached-679759d8f4-ssgkq -> schedule to Node k8s-worker-8
#  Pod user-timeline-redis-5976cd46bf-426xr -> schedule to Node k8s-worker-8
#  Pod social-graph-mongodb-d57786c7d-bnnc4 -> schedule to Node k8s-worker-9
# Starting migration of compose-post-service to k8s-worker-1
# Starting migration of text-service to k8s-worker-1
# Starting migration of post-storage-service to k8s-worker-1
# Starting migration of post-storage-mongodb to k8s-worker-1
# Starting migration of home-timeline-service to k8s-worker-1
# Starting migration of url-shorten-service to k8s-worker-1
# Starting migration of url-shorten-mongodb to k8s-worker-1
# Starting migration of user-timeline-service to k8s-worker-1
# Starting migration of user-timeline-mongodb to k8s-worker-1
# Starting migration of user-mention-service to k8s-worker-1
# Starting migration of user-memcached to k8s-worker-1
# Starting migration of home-timeline-redis to k8s-worker-2
# Starting migration of social-graph-redis to k8s-worker-2
# Starting migration of social-graph-service to k8s-worker-3
# Deployment 'text-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-frontend to k8s-worker-4
# Deployment 'post-storage-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of unique-id-service to k8s-worker-4
# Starting migration of media-memcached to k8s-worker-5
# Deployment 'compose-post-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of url-shorten-memcached to k8s-worker-5
# Deployment 'user-timeline-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-mongodb to k8s-worker-6
# Starting migration of user-mongodb to k8s-worker-6
# Deployment 'user-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-service to k8s-worker-7
# Deployment 'url-shorten-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-mention-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of user-service to k8s-worker-7
# Deployment 'home-timeline-redis' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Starting migration of post-storage-memcached to k8s-worker-8
# Deployment 'social-graph-service' patched to schedule pods on 'k8s-worker-3'.
# Waiting for the rolling update to complete...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-service migrated successfully to k8s-worker-1.
# Deployment 'media-frontend' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Starting migration of user-timeline-redis to k8s-worker-8
# Deployment 'unique-id-service' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-redis' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Starting migration of social-graph-mongodb to k8s-worker-9
# Deployment 'user-memcached' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Migration result: Migration of url-shorten-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-service migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-service to k8s-worker-1 completed.
# Deployment 'user-mongodb' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'media-mongodb' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-memcached' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'media-memcached' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'user-service' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-memcached' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# Deployment 'media-service' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-mongodb' patched to schedule pods on 'k8s-worker-9'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-redis' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of url-shorten-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-redis migrated successfully to k8s-worker-2.
# Migration result: Migration of home-timeline-redis to k8s-worker-2 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice text-service migrated successfully to k8s-worker-1.
# Migration result: Migration of text-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice compose-post-service migrated successfully to k8s-worker-1.
# Migration result: Migration of compose-post-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of home-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mention-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mention-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-frontend migrated successfully to k8s-worker-4.
# Migration result: Migration of media-frontend to k8s-worker-4 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-memcached migrated successfully to k8s-worker-5.
# Migration result: Migration of media-memcached to k8s-worker-5 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-memcached migrated successfully to k8s-worker-8.
# Migration result: Migration of post-storage-memcached to k8s-worker-8 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-mongodb migrated successfully to k8s-worker-6.
# Migration result: Migration of media-mongodb to k8s-worker-6 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-service migrated successfully to k8s-worker-7.
# Migration result: Migration of media-service to k8s-worker-7 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-redis migrated successfully to k8s-worker-8.
# Migration result: Migration of user-timeline-redis to k8s-worker-8 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-mongodb migrated successfully to k8s-worker-9.
# Migration result: Migration of social-graph-mongodb to k8s-worker-9 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-redis migrated successfully to k8s-worker-2.
# Migration result: Migration of social-graph-redis to k8s-worker-2 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mongodb migrated successfully to k8s-worker-6.
# Migration result: Migration of user-mongodb to k8s-worker-6 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-memcached migrated successfully to k8s-worker-1.
# Migration result: Migration of user-memcached to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-memcached migrated successfully to k8s-worker-5.
# Migration result: Migration of url-shorten-memcached to k8s-worker-5 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-service migrated successfully to k8s-worker-3.
# Migration result: Migration of social-graph-service to k8s-worker-3 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-service migrated successfully to k8s-worker-7.
# Migration result: Migration of user-service to k8s-worker-7 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice unique-id-service migrated successfully to k8s-worker-4.
# Migration result: Migration of unique-id-service to k8s-worker-4 completed.
# Average response time = 106.87 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 109.78 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 110.12 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 112.57 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 112.80 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 111.46 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 111.68 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 113.12 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 112.39 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 111.26 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 113.04 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 111.43 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 106.27 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 101.12 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 94.87 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 83.35 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 70.27 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 70.78 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 69.88 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 67.04 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 70.05 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 72.26 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 68.60 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 63.82 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 65.91 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 67.87 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 63.45 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 64.69 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 66.11 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 62.43 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 61.88 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 62.26 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 60.10 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 59.10 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 59.47 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.51 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 54.51 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 51.26 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 47.71 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 41.26 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.81 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.14 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.76 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.56 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 35.44 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 37.90 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 38.69 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.44 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.24 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.67 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.23 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.36 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.31 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.37 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.86 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.30 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.90 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.87 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.00 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.74 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 35.29 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.26 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 35.89 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.25 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# ...
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 26
#      23         time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds
#      25 time.sleep(60*16*2 + 60*3)
# ---> 26 evaluate_policy1_scheudlder()
#      28 # (1) before running the Policy1 scheduler, we run the workload for the first time
#      29 # to obtain performance in default k8s scheduler
#      30
#    (...)
#      42 # workload_thread.join()
#      43 # scheduler_thread.join()
#
# Cell In[2], line 23, in evaluate_policy1_scheudlder()
#      21 while True:
#      22     policy1.run()
# ---> 23     time.sleep(20)
#
# KeyboardInterrupt:

# %%
app1_prom_url = "http://10.105.116.175:9090"
app1_qos_target = 150  # QoS target in milliseconds
# time_window is the look_back window for the average response time
app1_time_window = 1  # Time window in minutes,
app1_namespace = 'social-network'
app1_response_code = '200'  # HTTP response code to consider

# Create an instance of the scheduler
policy1 = Policy1CallGraphAware()
policy1.initialize_policy(dynamics_config={"traffic_pairs": {}}, prom_url=app1_prom_url, 
                        qos_target = app1_qos_target, time_window = app1_time_window, 
                        namespace = app1_namespace, response_code = app1_response_code)

# Run the scheduler
while True:
    policy1.run()
    time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds

# %%
# 1) Gather cluster data
raw_nodes = gather_all_nodes()
candidate_nodes = build_nodeinfo_objects(raw_nodes)

# Gather pod data for each policy
# Deploye three instances of social-network application in different namespaces
# each policy will be applied to each namespace
raw_pods_Policy1 = gather_all_pods(namespace="social-network")
pods_Policy1 = build_podinfo_objects(raw_pods_Policy1)

raw_pods_Policy2 = gather_all_pods(namespace="social-network2")
pods_Policy2 = build_podinfo_objects(raw_pods_Policy2)

raw_pods_Policy3 = gather_all_pods(namespace="social-network3")
pods_Policy3 = build_podinfo_objects(raw_pods_Policy3)

# 2) (Optional) Build a call graph from 'graph_builder.py'
#    This might be used by Policy1 to place heavily communicating microservices.
G = build_call_graph(namespace="social-network")
# Convert the NetworkX graph to a simple dict: (src, dst) -> traffic_kb
traffic_matrix = {}
for (u, v, data) in G.edges(data=True):
    traffic_matrix[(u, v)] = data.get("weight", 0.0)  # store as KB

# 3) Initialize each policy with scenario-specific config
policy1 = Policy1CallGraphAware()
policy1.initialize_policy(dynamics_config={"traffic_matrix": traffic_matrix})

policy2 = Policy2LatencyAware()
policy2.initialize_policy(dynamics_config={"latency_threshold": 5.0})  # example

policy3 = Policy3BandwidthAware()
policy3.initialize_policy(dynamics_config={"high_traffic_threshold": 300.0})  # example

# 4) Choose which scenario you want to test
# Scenario 1: call-graph dynamics => we expect policy1 to shine
print("=== Scenario1: Call-Graph_Aware ===")
decisions_s1 = policy1.schedule_all(pods_Policy1, candidate_nodes)
for dec in decisions_s1:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")

# Scenario 2: cross-node delays => policy2 might do better
print("\n=== Scenario2: Latency_Aware ===")
decisions_s2 = policy2.schedule_all(pods_Policy2, candidate_nodes)
for dec in decisions_s2:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")

# Scenario 3: cross-node bandwidth changes => policy3 might do better
print("\n=== Scenario3: Bandwidth_Aware ===")
decisions_s3 = policy3.schedule_all(pods_Policy3, candidate_nodes)
for dec in decisions_s3:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")
