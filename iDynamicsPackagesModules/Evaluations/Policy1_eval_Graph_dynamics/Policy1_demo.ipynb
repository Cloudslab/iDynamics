# %%
from kubernetes import client, config
from typing import List
def gather_worker_nodes(exclude_node_name: str = 'k8s-master') -> List[client.V1Node]:
    """
    Quickly gather all nodes excluding 'k8s-master' using a field selector.
    """
    try:
        config.load_incluster_config()
    except:
        config.load_kube_config()

    v1 = client.CoreV1Api()
    raw_nodes = v1.list_node(field_selector=f'metadata.name!={exclude_node_name}').items
    return raw_nodes


worker_nodes = gather_worker_nodes()
print([node.metadata.name for node in worker_nodes])
# Out:
# ['k8s-worker-1', 'k8s-worker-2', 'k8s-worker-3', 'k8s-worker-4', 'k8s-worker-5', 'k8s-worker-6', 'k8s-worker-7', 'k8s-worker-8', 'k8s-worker-9']

# %%
# from Policy1_demo_workloads import wrk_different_requests
# from iDynamicsPackagesModules.SchedulingPolicyExtender.my_cluster_utils import (
#     gather_all_nodes, build_nodeinfo_objects,
#     build_podinfo_objects, gather_all_pods)

# from iDynamicsPackagesModules.GraphDynamicsAnalyzer.graph_builder import build_call_graph
from iDynamicsPackagesModules.Evaluations.Policy1_eval_Graph_dynamics.Policy1_Call_Graph_Aware import Policy1CallGraphAware
# from iDynamicsPackagesModules.Evaluations.Policy2_eval_Delay_dynamics.Policy2_Latency_Aware import Policy2LatencyAware
# from iDynamicsPackagesModules.Evaluations.Policy3_eval_Bandwidth_dynamics.Policy3_Bandwidth_Aware import Policy3BandwidthAware
# Out:
# Pods already exist in the namespace. Skipping DaemonSet deployment.
# {'k8s-worker-3': {'k8s-worker-3': None, 'k8s-worker-7': 3.6069999999999998, 'k8s-worker-5': 4.6080000000000005, 'k8s-worker-1': 0.6679999999999999, 'k8s-worker-2': 9.657, 'k8s-worker-9': 3.5149999999999997, 'k8s-worker-6': 8.493, 'k8s-worker-4': 2.525, 'k8s-worker-8': 16.625999999999998}, 'k8s-worker-9': {'k8s-worker-9': None, 'k8s-worker-1': 3.633, 'k8s-worker-6': 15.544, 'k8s-worker-3': 3.4979999999999998, 'k8s-worker-7': 11.644, 'k8s-worker-8': 7.551, 'k8s-worker-5': 19.593, 'k8s-worker-4': 15.563, 'k8s-worker-2': 11.399}, 'k8s-worker-7': {'k8s-worker-7': None, 'k8s-worker-6': 13.625, 'k8s-worker-3': 3.5239999999999996, 'k8s-worker-2': 16.604, 'k8s-worker-9': 11.556000000000001, 'k8s-worker-5': 11.533, 'k8s-worker-1': 6.588, 'k8s-worker-8': 18.589000000000002, 'k8s-worker-4': 15.599}, 'k8s-worker-6': {'k8s-worker-6': None, 'k8s-worker-9': 15.609, 'k8s-worker-1': 7.558, 'k8s-worker-8': 10.584, 'k8s-worker-3': 8.485, 'k8s-worker-4': 18.575000000000003, 'k8s-worker-2': 23.602999999999998, 'k8s-worker-5': 10.572, 'k8s-worker-7': 13.548}, 'k8s-worker-5': {'k8s-worker-5': None, 'k8s-worker-1': 5.624, 'k8s-worker-3': 4.624, 'k8s-worker-7': 11.502, 'k8s-worker-2': 11.588, 'k8s-worker-9': 19.613, 'k8s-worker-4': 6.507, 'k8s-worker-8': 13.679, 'k8s-worker-6': 10.581}, 'k8s-worker-1': {'k8s-worker-1': None, 'k8s-worker-3': 0.583, 'k8s-worker-7': 6.545999999999999, 'k8s-worker-5': 5.585, 'k8s-worker-4': 11.472, 'k8s-worker-6': 7.497, 'k8s-worker-2': 5.57, 'k8s-worker-9': 3.624, 'k8s-worker-8': 30.512}, 'k8s-worker-2': {'k8s-worker-2': None, 'k8s-worker-3': 9.734, 'k8s-worker-9': 11.408, 'k8s-worker-6': 23.66, 'k8s-worker-1': 5.682, 'k8s-worker-5': 11.495999999999999, 'k8s-worker-4': 12.542, 'k8s-worker-8': 39.499, 'k8s-worker-7': 16.597}, 'k8s-worker-8': {'k8s-worker-8': None, 'k8s-worker-9': 7.586, 'k8s-worker-6': 10.588000000000001, 'k8s-worker-5': 13.816, 'k8s-worker-3': 16.677999999999997, 'k8s-worker-7': 18.633, 'k8s-worker-1': 30.544, 'k8s-worker-2': 39.565000000000005, 'k8s-worker-4': 20.654}, 'k8s-worker-4': {'k8s-worker-4': None, 'k8s-worker-9': 15.698, 'k8s-worker-3': 2.697, 'k8s-worker-5': 6.502, 'k8s-worker-6': 18.723, 'k8s-worker-7': 15.555, 'k8s-worker-1': 11.700999999999999, 'k8s-worker-2': 12.686, 'k8s-worker-8': 20.6}}

# %%
# request_A_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/compose-post.lua"
# request_B_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-home-timeline.lua"
# request_C_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/read-user-timeline.lua"

# request_mix_script_path = "/home/ubuntu/DeathStarBench/socialNetwork/wrk2/scripts/social-network/mixed-workload.lua" # default mix percentage: 60% A, 30% B, 10% C

# script_path = [
#     request_A_script_path,
#     request_B_script_path,
#     request_C_script_path,
#     request_mix_script_path
# ]

# url = [
#     #diffferent namespace of social-network Application
#     "http://nginx-thrift.social-network.svc.cluster.local:8080",       # in namespace of "social-network"
#     "http://nginx-thrift.social-network2.svc.cluster.local:8080",
#    "http://nginx-thrift.social-network3.svc.cluster.local:8080"
# ]

# each_wrk_duration = "30s" # eg., "30s", "1m", 5m", "10m", "15m"

# for j in range(0, len(url)):
#     for i in range(0, len(script_path)):

#         wrk_different_requests(script_path[i], url[j], request_interval = each_wrk_duration)

# %%
import time
# Initialize the scheduler with necessary parameters
app1_prom_url = "http://10.105.116.175:9090"
app1_qos_target = 250  # QoS target in milliseconds
# time_window is the look_back window for the average response time
app1_time_window = 1  # Time window in minutes,
app1_namespace = 'social-network'
app1_response_code = '200'  # HTTP response code to consider

# Create an instance of the scheduler
policy1 = Policy1CallGraphAware()
policy1.initialize_policy(dynamics_config={"traffic_matrix": {}}, prom_url=app1_prom_url, 
                          qos_target = app1_qos_target, time_window = app1_time_window, 
                          namespace = app1_namespace, response_code = app1_response_code)

# Run the scheduler
while True:
    policy1.run()
    time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds
# Out:
# Average response time = 194.35 ms
# Trigger = True
# Ready Deployments: ['compose-post-service', 'home-timeline-redis', 'home-timeline-service', 'jaeger', 'media-frontend', 'media-memcached', 'media-mongodb', 'media-service', 'nginx-thrift', 'post-storage-memcached', 'post-storage-mongodb', 'post-storage-service', 'social-graph-mongodb', 'social-graph-redis', 'social-graph-service', 'text-service', 'unique-id-service', 'url-shorten-memcached', 'url-shorten-mongodb', 'url-shorten-service', 'user-memcached', 'user-mention-service', 'user-mongodb', 'user-service', 'user-timeline-mongodb', 'user-timeline-redis', 'user-timeline-service']
# from compose-post-service to home-timeline-service ~ 19.0 KB
# from compose-post-service to media-service ~ 26.9 KB
# from compose-post-service to post-storage-service ~ 105.6 KB
# from compose-post-service to text-service ~ 145.2 KB
# from compose-post-service to unique-id-service ~ 16.5 KB
# from compose-post-service to user-service ~ 22.5 KB
# from compose-post-service to user-timeline-service ~ 18.2 KB
# from home-timeline-service to home-timeline-redis ~ 5.8 KB
# from home-timeline-service to post-storage-service ~ 19.6 KB
# from home-timeline-service to social-graph-service ~ 16.0 KB
# from nginx-thrift to compose-post-service ~ 76.5 KB
# from nginx-thrift to home-timeline-service ~ 23.3 KB
# from nginx-thrift to user-timeline-service ~ 301.3 KB
# from post-storage-service to post-storage-memcached ~ 594.3 KB
# from post-storage-service to post-storage-mongodb ~ 287.2 KB
# from social-graph-service to social-graph-mongodb ~ 24.7 KB
# from social-graph-service to social-graph-redis ~ 5.2 KB
# from text-service to url-shorten-service ~ 77.9 KB
# from text-service to user-mention-service ~ 22.3 KB
# from url-shorten-service to url-shorten-mongodb ~ 0.0 KB
# from user-mention-service to user-memcached ~ 23.5 KB
# from user-mention-service to user-mongodb ~ 0.0 KB
# from user-service to user-mongodb ~ 0.0 KB
# from user-timeline-service to post-storage-service ~ 334.3 KB
# from user-timeline-service to user-timeline-mongodb ~ 814.6 KB
# from user-timeline-service to user-timeline-redis ~ 30.7 KB
# [Policy1CallGraphAware] Updated traffic matrix for app in namespace social-network with 23 edges.
# === Scenario1: Call-Graph_Aware ===
#  Pod user-timeline-service-6c7b9c48bc-m9j2r -> schedule to Node k8s-worker-1
#  Pod user-timeline-mongodb-865c9c4975-clxc4 -> schedule to Node k8s-worker-1
#  Pod post-storage-service-696b99f894-486sz -> schedule to Node k8s-worker-1
#  Pod post-storage-memcached-786b6455f-tkbg2 -> schedule to Node k8s-worker-1
#  Pod compose-post-service-79fffc8f65-tvnvd -> schedule to Node k8s-worker-1
#  Pod text-service-84d48878-pmdx8 -> schedule to Node k8s-worker-1
#  Pod social-graph-service-7f767545d4-vrggp -> schedule to Node k8s-worker-1
#  Pod social-graph-mongodb-7db6d5b58-jn2bk -> schedule to Node k8s-worker-1
#  Pod user-mention-service-6f9554bdfd-7bmxx -> schedule to Node k8s-worker-1
#  Pod user-memcached-8474bbc969-24shr -> schedule to Node k8s-worker-1
#  Pod nginx-thrift-7f77f9f9df-b5tww -> schedule to Node k8s-worker-1
#  Pod home-timeline-service-5847cc645f-sn5x5 -> schedule to Node k8s-worker-1
#  Pod home-timeline-redis-74777776d8-79l77 -> schedule to Node k8s-worker-2
#  Pod unique-id-service-78db644977-hkbs5 -> schedule to Node k8s-worker-2
#  Pod jaeger-7d4cb8c8db-lcz5j -> schedule to Node k8s-worker-3
#  Pod url-shorten-memcached-645954f675-nvgsh -> schedule to Node k8s-worker-3
#  Pod media-frontend-6f8b6db9bb-2bpb5 -> schedule to Node k8s-worker-4
#  Pod url-shorten-mongodb-5d6779b787-78dq5 -> schedule to Node k8s-worker-4
#  Pod media-memcached-5584c4bbdf-z96sv -> schedule to Node k8s-worker-5
#  Pod url-shorten-service-8487489949-qdctx -> schedule to Node k8s-worker-5
#  Pod media-mongodb-6fd7768d66-9kqg6 -> schedule to Node k8s-worker-6
#  Pod user-mongodb-54f7856897-kmfv7 -> schedule to Node k8s-worker-6
#  Pod media-service-7fbfc5f4c-gfbdk -> schedule to Node k8s-worker-7
#  Pod user-service-64b5d876b-gb9s2 -> schedule to Node k8s-worker-7
#  Pod post-storage-mongodb-6cd66b64db-dv9rv -> schedule to Node k8s-worker-8
#  Pod user-timeline-redis-75647777b4-g6dsn -> schedule to Node k8s-worker-8
#  Pod social-graph-redis-6b4dcf589-hgqs6 -> schedule to Node k8s-worker-9
# Starting migration of user-timeline-service to k8s-worker-1
# Starting migration of user-timeline-mongodb to k8s-worker-1
# Starting migration of post-storage-service to k8s-worker-1
# Starting migration of post-storage-memcached to k8s-worker-1
# Starting migration of compose-post-service to k8s-worker-1
# Starting migration of text-service to k8s-worker-1
# Starting migration of social-graph-service to k8s-worker-1
# Starting migration of social-graph-mongodb to k8s-worker-1
# Starting migration of user-mention-service to k8s-worker-1
# Starting migration of user-memcached to k8s-worker-1
# Starting migration of nginx-thrift to k8s-worker-1
# Starting migration of home-timeline-service to k8s-worker-1
# Starting migration of home-timeline-redis to k8s-worker-2
# Starting migration of unique-id-service to k8s-worker-2
# Starting migration of jaeger to k8s-worker-3
# Starting migration of url-shorten-memcached to k8s-worker-3
# Starting migration of media-frontend to k8s-worker-4
# Starting migration of url-shorten-mongodb to k8s-worker-4
# Starting migration of media-memcached to k8s-worker-5
# Starting migration of url-shorten-service to k8s-worker-5
# Starting migration of media-mongodb to k8s-worker-6
# Starting migration of user-mongodb to k8s-worker-6
# Starting migration of media-service to k8s-worker-7
# Starting migration of user-service to k8s-worker-7
# Starting migration of post-storage-mongodb to k8s-worker-8
# Starting migration of user-timeline-redis to k8s-worker-8
# Starting migration of social-graph-redis to k8s-worker-9
# Deployment 'user-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'compose-post-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-mongodb' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'user-memcached' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-memcached' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-service' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'user-service' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# Deployment 'media-memcached' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'user-mongodb' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'media-service' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-memcached' patched to schedule pods on 'k8s-worker-3'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-redis' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# Deployment 'media-frontend' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'media-mongodb' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-redis' patched to schedule pods on 'k8s-worker-9'.
# Waiting for the rolling update to complete...
# Deployment 'unique-id-service' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-redis' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'text-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'jaeger' patched to schedule pods on 'k8s-worker-3'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-mongodb' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# Deployment 'nginx-thrift' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-mention-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-service migrated successfully to k8s-worker-7.
# Migration result: Migration of user-service to k8s-worker-7 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-redis migrated successfully to k8s-worker-9.
# Migration result: Migration of social-graph-redis to k8s-worker-9 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-mongodb migrated successfully to k8s-worker-6.
# Migration result: Migration of media-mongodb to k8s-worker-6 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-mongodb migrated successfully to k8s-worker-4.
# Migration result: Migration of url-shorten-mongodb to k8s-worker-4 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-mongodb migrated successfully to k8s-worker-8.
# Migration result: Migration of post-storage-mongodb to k8s-worker-8 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mongodb migrated successfully to k8s-worker-6.
# Migration result: Migration of user-mongodb to k8s-worker-6 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-memcached migrated successfully to k8s-worker-5.
# Migration result: Migration of media-memcached to k8s-worker-5 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-redis migrated successfully to k8s-worker-8.
# Migration result: Migration of user-timeline-redis to k8s-worker-8 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-redis migrated successfully to k8s-worker-2.
# Migration result: Migration of home-timeline-redis to k8s-worker-2 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-memcached migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-memcached to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-service migrated successfully to k8s-worker-5.
# Migration result: Migration of url-shorten-service to k8s-worker-5 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-service migrated successfully to k8s-worker-7.
# Migration result: Migration of media-service to k8s-worker-7 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-memcached migrated successfully to k8s-worker-3.
# Migration result: Migration of url-shorten-memcached to k8s-worker-3 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice unique-id-service migrated successfully to k8s-worker-2.
# Migration result: Migration of unique-id-service to k8s-worker-2 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice jaeger migrated successfully to k8s-worker-3.
# Migration result: Migration of jaeger to k8s-worker-3 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-memcached migrated successfully to k8s-worker-1.
# Migration result: Migration of user-memcached to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-service migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice text-service migrated successfully to k8s-worker-1.
# Migration result: Migration of text-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice compose-post-service migrated successfully to k8s-worker-1.
# Migration result: Migration of compose-post-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of home-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-service migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-frontend migrated successfully to k8s-worker-4.
# Migration result: Migration of media-frontend to k8s-worker-4 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mention-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mention-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice nginx-thrift migrated successfully to k8s-worker-1.
# Migration result: Migration of nginx-thrift to k8s-worker-1 completed.
# Average response time = 157.81 ms
# Trigger = True
# Ready Deployments: ['compose-post-service', 'home-timeline-redis', 'home-timeline-service', 'jaeger', 'media-frontend', 'media-memcached', 'media-mongodb', 'media-service', 'nginx-thrift', 'post-storage-memcached', 'post-storage-mongodb', 'post-storage-service', 'social-graph-mongodb', 'social-graph-redis', 'social-graph-service', 'text-service', 'unique-id-service', 'url-shorten-memcached', 'url-shorten-mongodb', 'url-shorten-service', 'user-memcached', 'user-mention-service', 'user-mongodb', 'user-service', 'user-timeline-mongodb', 'user-timeline-redis', 'user-timeline-service']
# from compose-post-service to home-timeline-service ~ 15.9 KB
# from compose-post-service to media-service ~ 22.5 KB
# from compose-post-service to post-storage-service ~ 88.5 KB
# from compose-post-service to text-service ~ 121.9 KB
# from compose-post-service to unique-id-service ~ 13.8 KB
# from compose-post-service to user-service ~ 18.8 KB
# from compose-post-service to user-timeline-service ~ 15.3 KB
# from home-timeline-service to home-timeline-redis ~ 6.5 KB
# from home-timeline-service to post-storage-service ~ 22.1 KB
# from home-timeline-service to social-graph-service ~ 13.4 KB
# from nginx-thrift to compose-post-service ~ 60.6 KB
# from nginx-thrift to home-timeline-service ~ 26.2 KB
# from nginx-thrift to user-timeline-service ~ 428.3 KB
# from post-storage-service to post-storage-memcached ~ 810.3 KB
# from post-storage-service to post-storage-mongodb ~ 0.6 KB
# from social-graph-service to social-graph-mongodb ~ 20.8 KB
# from social-graph-service to social-graph-redis ~ 4.3 KB
# from text-service to url-shorten-service ~ 65.4 KB
# from text-service to user-mention-service ~ 18.6 KB
# from url-shorten-service to url-shorten-mongodb ~ 0.0 KB
# from user-mention-service to user-memcached ~ 19.9 KB
# from user-mention-service to user-mongodb ~ 0.0 KB
# from user-service to user-mongodb ~ 0.0 KB
# from user-timeline-service to post-storage-service ~ 466.5 KB
# from user-timeline-service to user-timeline-mongodb ~ 0.0 KB
# from user-timeline-service to user-timeline-redis ~ 36.9 KB
# [Policy1CallGraphAware] Updated traffic matrix for app in namespace social-network with 22 edges.
# === Scenario1: Call-Graph_Aware ===
#  Pod post-storage-service-665799f78d-d6t47 -> schedule to Node k8s-worker-1
#  Pod post-storage-memcached-74b5998795-hzq69 -> schedule to Node k8s-worker-1
#  Pod nginx-thrift-69d4b76ddf-72ztj -> schedule to Node k8s-worker-1
#  Pod user-timeline-service-69b9bf6d6f-9jngq -> schedule to Node k8s-worker-1
#  Pod compose-post-service-5577db79f5-qfvxk -> schedule to Node k8s-worker-1
#  Pod text-service-7fc68b959d-xnk82 -> schedule to Node k8s-worker-1
#  Pod social-graph-service-695bd7747d-xnln8 -> schedule to Node k8s-worker-1
#  Pod social-graph-mongodb-d57786c7d-fxmlv -> schedule to Node k8s-worker-1
#  Pod user-mention-service-954dbd6f6-vxcg5 -> schedule to Node k8s-worker-1
#  Pod user-memcached-5d9dd9899-fq6cn -> schedule to Node k8s-worker-1
#  Pod home-timeline-service-765d6df88f-ggrtr -> schedule to Node k8s-worker-1
#  Pod home-timeline-redis-5b66669785-prs6b -> schedule to Node k8s-worker-1
#  Pod jaeger-cf68b4674-dg55z -> schedule to Node k8s-worker-2
#  Pod url-shorten-memcached-69f9c56b67-s5qg4 -> schedule to Node k8s-worker-2
#  Pod media-frontend-f9d45f8c9-gswgx -> schedule to Node k8s-worker-3
#  Pod url-shorten-mongodb-59fc4f756d-ch7vl -> schedule to Node k8s-worker-3
#  Pod media-memcached-5b8b4b94c7-qd5gr -> schedule to Node k8s-worker-4
#  Pod url-shorten-service-6d8bf46d7-b4g4q -> schedule to Node k8s-worker-4
#  Pod media-mongodb-78b59c496c-sbfr5 -> schedule to Node k8s-worker-5
#  Pod user-mongodb-cb79cbf66-b49d2 -> schedule to Node k8s-worker-5
#  Pod media-service-cbcdcbfb9-9gq6d -> schedule to Node k8s-worker-6
#  Pod user-service-75bdf9979b-l29ld -> schedule to Node k8s-worker-6
#  Pod post-storage-mongodb-c74dc6ddc-bkj4h -> schedule to Node k8s-worker-7
#  Pod user-timeline-mongodb-569fc84d55-bjjzr -> schedule to Node k8s-worker-7
#  Pod social-graph-redis-7c9c8db9d5-2c2th -> schedule to Node k8s-worker-8
#  Pod user-timeline-redis-7dc56d56f9-t52zg -> schedule to Node k8s-worker-8
#  Pod unique-id-service-78bcf54fdb-9sfpt -> schedule to Node k8s-worker-9
# Starting migration of post-storage-service to k8s-worker-1
# Starting migration of post-storage-memcached to k8s-worker-1
# Starting migration of nginx-thrift to k8s-worker-1
# Starting migration of user-timeline-service to k8s-worker-1
# Starting migration of compose-post-service to k8s-worker-1
# Starting migration of text-service to k8s-worker-1
# Starting migration of social-graph-service to k8s-worker-1
# Starting migration of social-graph-mongodb to k8s-worker-1
# Starting migration of user-mention-service to k8s-worker-1
# Starting migration of user-memcached to k8s-worker-1
# Starting migration of home-timeline-service to k8s-worker-1
# Starting migration of home-timeline-redis to k8s-worker-1
# Starting migration of jaeger to k8s-worker-2
# Starting migration of url-shorten-memcached to k8s-worker-2
# Starting migration of media-frontend to k8s-worker-3
# Starting migration of url-shorten-mongodb to k8s-worker-3
# Starting migration of media-memcached to k8s-worker-4
# Deployment 'compose-post-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of url-shorten-service to k8s-worker-4
# Deployment 'post-storage-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-mongodb to k8s-worker-5
# Deployment 'social-graph-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of user-mongodb to k8s-worker-5
# Deployment 'text-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-mention-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-memcached' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'jaeger' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Deployment 'nginx-thrift' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-memcached' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-service to k8s-worker-6
# Starting migration of user-service to k8s-worker-6
# Deployment 'social-graph-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of post-storage-mongodb to k8s-worker-7
# Starting migration of user-timeline-mongodb to k8s-worker-7
# Starting migration of social-graph-redis to k8s-worker-8
# Starting migration of user-timeline-redis to k8s-worker-8
# Starting migration of unique-id-service to k8s-worker-9
# Deployment 'url-shorten-service' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'media-service' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-mongodb' patched to schedule pods on 'k8s-worker-3'.
# Waiting for the rolling update to complete...
# Deployment 'user-service' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'media-mongodb' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-mongodb' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-redis' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# Deployment 'media-memcached' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'unique-id-service' patched to schedule pods on 'k8s-worker-9'.
# Waiting for the rolling update to complete...
# Deployment 'user-mongodb' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-redis' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-memcached' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-mongodb' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-redis' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# Deployment 'media-frontend' patched to schedule pods on 'k8s-worker-3'.
# Waiting for the rolling update to complete...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-service migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice nginx-thrift migrated successfully to k8s-worker-1.
# Migration result: Migration of nginx-thrift to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of home-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice compose-post-service migrated successfully to k8s-worker-1.
# Migration result: Migration of compose-post-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-memcached migrated successfully to k8s-worker-1.
# Migration result: Migration of user-memcached to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-memcached migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-memcached to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice text-service migrated successfully to k8s-worker-1.
# Migration result: Migration of text-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mention-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mention-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-service migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-redis migrated successfully to k8s-worker-8.
# Migration result: Migration of user-timeline-redis to k8s-worker-8 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-memcached migrated successfully to k8s-worker-4.
# Migration result: Migration of media-memcached to k8s-worker-4 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-mongodb migrated successfully to k8s-worker-7.
# Migration result: Migration of user-timeline-mongodb to k8s-worker-7 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mongodb migrated successfully to k8s-worker-5.
# Migration result: Migration of user-mongodb to k8s-worker-5 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-mongodb migrated successfully to k8s-worker-5.
# Migration result: Migration of media-mongodb to k8s-worker-5 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-mongodb migrated successfully to k8s-worker-3.
# Migration result: Migration of url-shorten-mongodb to k8s-worker-3 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-redis migrated successfully to k8s-worker-1.
# Migration result: Migration of home-timeline-redis to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-redis migrated successfully to k8s-worker-8.
# Migration result: Migration of social-graph-redis to k8s-worker-8 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-mongodb migrated successfully to k8s-worker-7.
# Migration result: Migration of post-storage-mongodb to k8s-worker-7 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-memcached migrated successfully to k8s-worker-2.
# Migration result: Migration of url-shorten-memcached to k8s-worker-2 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice jaeger migrated successfully to k8s-worker-2.
# Migration result: Migration of jaeger to k8s-worker-2 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-service migrated successfully to k8s-worker-4.
# Migration result: Migration of url-shorten-service to k8s-worker-4 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-service migrated successfully to k8s-worker-6.
# Migration result: Migration of media-service to k8s-worker-6 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-service migrated successfully to k8s-worker-6.
# Migration result: Migration of user-service to k8s-worker-6 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice unique-id-service migrated successfully to k8s-worker-9.
# Migration result: Migration of unique-id-service to k8s-worker-9 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-frontend migrated successfully to k8s-worker-3.
# Migration result: Migration of media-frontend to k8s-worker-3 completed.
# Query returned no data, no trigger.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Query returned no data, no trigger.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Query returned no data, no trigger.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Query returned no data, no trigger.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Query returned no data, no trigger.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Query returned no data, no trigger.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Query returned no data, no trigger.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Query returned no data, no trigger.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 19
#      17 while True:
#      18     policy1.run()
# ---> 19     time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds
#
# KeyboardInterrupt:

# %%
# 1) Gather cluster data
raw_nodes = gather_all_nodes()
candidate_nodes = build_nodeinfo_objects(raw_nodes)

# Gather pod data for each policy
# Deploye three instances of social-network application in different namespaces
# each policy will be applied to each namespace
raw_pods_Policy1 = gather_all_pods(namespace="social-network")
pods_Policy1 = build_podinfo_objects(raw_pods_Policy1)

raw_pods_Policy2 = gather_all_pods(namespace="social-network2")
pods_Policy2 = build_podinfo_objects(raw_pods_Policy2)

raw_pods_Policy3 = gather_all_pods(namespace="social-network3")
pods_Policy3 = build_podinfo_objects(raw_pods_Policy3)

# 2) (Optional) Build a call graph from 'graph_builder.py'
#    This might be used by Policy1 to place heavily communicating microservices.
G = build_call_graph(namespace="social-network")
# Convert the NetworkX graph to a simple dict: (src, dst) -> traffic_kb
traffic_matrix = {}
for (u, v, data) in G.edges(data=True):
    traffic_matrix[(u, v)] = data.get("weight", 0.0)  # store as KB

# 3) Initialize each policy with scenario-specific config
policy1 = Policy1CallGraphAware()
policy1.initialize_policy(dynamics_config={"traffic_matrix": traffic_matrix})

policy2 = Policy2LatencyAware()
policy2.initialize_policy(dynamics_config={"latency_threshold": 5.0})  # example

policy3 = Policy3BandwidthAware()
policy3.initialize_policy(dynamics_config={"high_traffic_threshold": 300.0})  # example

# 4) Choose which scenario you want to test
# Scenario 1: call-graph dynamics => we expect policy1 to shine
print("=== Scenario1: Call-Graph_Aware ===")
decisions_s1 = policy1.schedule_all(pods_Policy1, candidate_nodes)
for dec in decisions_s1:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")

# Scenario 2: cross-node delays => policy2 might do better
print("\n=== Scenario2: Latency_Aware ===")
decisions_s2 = policy2.schedule_all(pods_Policy2, candidate_nodes)
for dec in decisions_s2:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")

# Scenario 3: cross-node bandwidth changes => policy3 might do better
print("\n=== Scenario3: Bandwidth_Aware ===")
decisions_s3 = policy3.schedule_all(pods_Policy3, candidate_nodes)
for dec in decisions_s3:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")
