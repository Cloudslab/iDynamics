# %%
# from Policy1_demo_workloads import wrk_different_requests
# from iDynamicsPackagesModules.SchedulingPolicyExtender.my_cluster_utils import (
#     gather_all_nodes, build_nodeinfo_objects,
#     build_podinfo_objects, gather_all_pods)

# from iDynamicsPackagesModules.GraphDynamicsAnalyzer.graph_builder import build_call_graph
from iDynamicsPackagesModules.Evaluations.Cluster_15_Nodes.Policy1_eval_Graph_dynamics.Policy1_Call_Graph_Aware import Policy1CallGraphAware
# from iDynamicsPackagesModules.Evaluations.Policy2_eval_Delay_dynamics.Policy2_Latency_Aware import Policy2LatencyAware
# from iDynamicsPackagesModules.Evaluations.Policy3_eval_Bandwidth_dynamics.Policy3_Bandwidth_Aware import Policy3BandwidthAware

# from Policy1_demo_workloads import run_workload_varing_callGraph

# %%
import time
import threading


def evaluate_policy1_scheudlder():
    # Initialize the scheduler with necessary parameters
    app1_prom_url = "http://10.105.116.175:9090"
    app1_qos_target = 200 #150 ms for 10 cluster nodes,  200 ms for 15 cluster nodes  # QoS target in milliseconds
    # time_window is the look_back window for the average response time
    app1_time_window = 1  # Time window in minutes,
    app1_namespace = 'social-network'
    app1_response_code = '200'  # HTTP response code to consider

    # Create an instance of the scheduler
    policy1 = Policy1CallGraphAware()
    policy1.initialize_policy(dynamics_config={"traffic_pairs": {}}, prom_url=app1_prom_url, 
                            qos_target = app1_qos_target, time_window = app1_time_window, 
                            namespace = app1_namespace, response_code = app1_response_code)

    # Run the scheduler
    while True:
        policy1.run()
        time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds

# wait 60*16*2 seconds till the default k8s policy evaluation first, and then Policy1
# 60*3 seconds is the sleep time two evaluations (default k8s policy first, and then Policy1)
# time.sleep(60*16*2 + 60*3) 
evaluate_policy1_scheudlder()

# (1) before running the Policy1 scheduler, we run the workload for the first time 
# to obtain performance in default k8s scheduler

# run_workload_varing_callGraph(each_wrk2_duration='3m') # eg., "30s", "1m", 5m", "10m", "15m"
#sleep for 2 mins
# time.sleep(180)

# (2) Conccurently run evaluate_policy1_scheudlder() and run_workload_varing_callGraph()
# workload_thread = threading.Thread(target = run_workload_varing_callGraph, kwargs={'each_wrk2_duration':'3m'})
# scheduler_thread = threading.Thread(target=evaluate_policy1_scheudlder)
# workload_thread.start()
# scheduler_thread.start()

# # Wait for both threads to finish
# workload_thread.join()
# scheduler_thread.join()
# Out:
# Average response time = 64.97 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 68.21 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 147.41 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 38.03 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.22 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 40.43 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.85 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.48 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 40.23 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 40.97 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 40.67 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 40.52 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 41.78 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 42.89 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 41.72 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.62 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.27 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.57 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.10 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.20 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.42 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.20 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.14 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.17 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.08 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 38.98 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.01 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 51.36 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 90.68 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 92.85 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 116.97 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 214.03 ms
# Trigger = True
# Ready Deployments: ['compose-post-service', 'home-timeline-redis', 'home-timeline-service', 'jaeger', 'media-frontend', 'media-memcached', 'media-mongodb', 'media-service', 'nginx-thrift', 'post-storage-memcached', 'post-storage-mongodb', 'post-storage-service', 'social-graph-mongodb', 'social-graph-redis', 'social-graph-service', 'text-service', 'unique-id-service', 'url-shorten-memcached', 'url-shorten-mongodb', 'url-shorten-service', 'user-memcached', 'user-mention-service', 'user-mongodb', 'user-service', 'user-timeline-mongodb', 'user-timeline-redis', 'user-timeline-service']
# from compose-post-service to home-timeline-service ~ 26.1 KB
# from compose-post-service to media-service ~ 37.6 KB
# from compose-post-service to post-storage-service ~ 148.1 KB
# from compose-post-service to text-service ~ 204.0 KB
# from compose-post-service to unique-id-service ~ 23.6 KB
# from compose-post-service to user-service ~ 32.0 KB
# from compose-post-service to user-timeline-service ~ 25.8 KB
# from home-timeline-service to home-timeline-redis ~ 39.6 KB
# from home-timeline-service to post-storage-service ~ 133.1 KB
# from home-timeline-service to social-graph-service ~ 21.0 KB
# from nginx-thrift to compose-post-service ~ 103.8 KB
# from nginx-thrift to home-timeline-service ~ 158.8 KB
# from nginx-thrift to user-timeline-service ~ 0.0 KB
# from post-storage-service to post-storage-memcached ~ 0.0 KB
# from post-storage-service to post-storage-mongodb ~ 188.6 KB
# from social-graph-service to social-graph-mongodb ~ 36.5 KB
# from social-graph-service to social-graph-redis ~ 7.7 KB
# from text-service to url-shorten-service ~ 101.4 KB
# from text-service to user-mention-service ~ 28.9 KB
# from url-shorten-service to url-shorten-mongodb ~ 0.0 KB
# from user-mention-service to user-memcached ~ 34.0 KB
# from user-mention-service to user-mongodb ~ 40.4 KB
# from user-service to user-mongodb ~ 1.0 KB
# from user-timeline-service to post-storage-service ~ 0.0 KB
# from user-timeline-service to user-timeline-mongodb ~ 194.3 KB
# from user-timeline-service to user-timeline-redis ~ 11.7 KB
# [Policy1CallGraphAware] Updated traffic matrix for app in namespace social-network with 22 edges.
# === Scenario1: Call-Graph_Aware ===
#  Pod compose-post-service-79fffc8f65-6t6g5 -> schedule to Node k8s-worker-1
#  Pod text-service-84d48878-wl2xg -> schedule to Node k8s-worker-1
#  Pod user-timeline-service-6c7b9c48bc-qdkhm -> schedule to Node k8s-worker-1
#  Pod user-timeline-mongodb-865c9c4975-bhjk7 -> schedule to Node k8s-worker-1
#  Pod post-storage-service-696b99f894-t6j6q -> schedule to Node k8s-worker-1
#  Pod post-storage-mongodb-6cd66b64db-86h4w -> schedule to Node k8s-worker-1
#  Pod home-timeline-service-5847cc645f-hdl7j -> schedule to Node k8s-worker-1
#  Pod user-mention-service-6f9554bdfd-bdlcd -> schedule to Node k8s-worker-1
#  Pod user-mongodb-54f7856897-bm2fq -> schedule to Node k8s-worker-1
#  Pod social-graph-service-7f767545d4-dl94l -> schedule to Node k8s-worker-1
#  Pod social-graph-mongodb-7db6d5b58-qxr2m -> schedule to Node k8s-worker-1
#  Pod home-timeline-redis-74777776d8-c4kkq -> schedule to Node k8s-worker-10
#  Pod user-service-64b5d876b-6mwm5 -> schedule to Node k8s-worker-10
#  Pod user-timeline-redis-75647777b4-9f99h -> schedule to Node k8s-worker-11
#  Pod media-frontend-6f8b6db9bb-627c4 -> schedule to Node k8s-worker-12
#  Pod media-memcached-5584c4bbdf-dnxr4 -> schedule to Node k8s-worker-13
#  Pod media-mongodb-6fd7768d66-vtlr7 -> schedule to Node k8s-worker-14
#  Pod media-service-7fbfc5f4c-m8jw9 -> schedule to Node k8s-worker-2
#  Pod post-storage-memcached-786b6455f-q82gm -> schedule to Node k8s-worker-3
#  Pod social-graph-redis-6b4dcf589-ghr6z -> schedule to Node k8s-worker-4
#  Pod unique-id-service-78db644977-wc7hn -> schedule to Node k8s-worker-5
#  Pod url-shorten-memcached-645954f675-g7tjw -> schedule to Node k8s-worker-6
#  Pod url-shorten-mongodb-5d6779b787-zbznf -> schedule to Node k8s-worker-7
#  Pod url-shorten-service-8487489949-27wp2 -> schedule to Node k8s-worker-8
#  Pod user-memcached-8474bbc969-dm48p -> schedule to Node k8s-worker-9
# Starting migration of compose-post-service to k8s-worker-1
# Starting migration of text-service to k8s-worker-1
# Starting migration of user-timeline-service to k8s-worker-1
# Starting migration of user-timeline-mongodb to k8s-worker-1
# Starting migration of post-storage-service to k8s-worker-1
# Starting migration of post-storage-mongodb to k8s-worker-1
# Starting migration of home-timeline-service to k8s-worker-1
# Starting migration of user-mention-service to k8s-worker-1
# Starting migration of user-mongodb to k8s-worker-1
# Starting migration of social-graph-service to k8s-worker-1
# Starting migration of social-graph-mongodb to k8s-worker-1
# Starting migration of home-timeline-redis to k8s-worker-10
# Starting migration of user-service to k8s-worker-10
# Starting migration of user-timeline-redis to k8s-worker-11
# Starting migration of media-frontend to k8s-worker-12
# Starting migration of media-memcached to k8s-worker-13
# Deployment 'compose-post-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-mongodb to k8s-worker-14
# Starting migration of media-service to k8s-worker-2
# Starting migration of post-storage-memcached to k8s-worker-3
# Deployment 'user-timeline-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-mention-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of social-graph-redis to k8s-worker-4
# Deployment 'home-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'text-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of unique-id-service to k8s-worker-5
# Deployment 'post-storage-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of url-shorten-memcached to k8s-worker-6
# Starting migration of url-shorten-mongodb to k8s-worker-7
# Starting migration of url-shorten-service to k8s-worker-8
# Starting migration of user-memcached to k8s-worker-9
# Deployment 'user-timeline-redis' patched to schedule pods on 'k8s-worker-11'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'media-memcached' patched to schedule pods on 'k8s-worker-13'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-redis' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-redis' patched to schedule pods on 'k8s-worker-10'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-service' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# Deployment 'media-mongodb' patched to schedule pods on 'k8s-worker-14'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'unique-id-service' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'user-service' patched to schedule pods on 'k8s-worker-10'.
# Waiting for the rolling update to complete...
# Deployment 'media-service' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-mongodb' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# Deployment 'media-frontend' patched to schedule pods on 'k8s-worker-12'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-memcached' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'user-memcached' patched to schedule pods on 'k8s-worker-9'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-memcached' patched to schedule pods on 'k8s-worker-3'.
# Waiting for the rolling update to complete...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 2
# All pods are running on the new node.
# Microservice user-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 2
# All pods are running on the new node.
# Microservice post-storage-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-redis migrated successfully to k8s-worker-4.
# Migration result: Migration of social-graph-redis to k8s-worker-4 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-mongodb migrated successfully to k8s-worker-7.
# Migration result: Migration of url-shorten-mongodb to k8s-worker-7 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-memcached migrated successfully to k8s-worker-6.
# Migration result: Migration of url-shorten-memcached to k8s-worker-6 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-memcached migrated successfully to k8s-worker-9.
# Migration result: Migration of user-memcached to k8s-worker-9 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-redis migrated successfully to k8s-worker-11.
# Migration result: Migration of user-timeline-redis to k8s-worker-11 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-memcached migrated successfully to k8s-worker-13.
# Migration result: Migration of media-memcached to k8s-worker-13 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-memcached migrated successfully to k8s-worker-3.
# Migration result: Migration of post-storage-memcached to k8s-worker-3 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-redis migrated successfully to k8s-worker-10.
# Migration result: Migration of home-timeline-redis to k8s-worker-10 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-service migrated successfully to k8s-worker-8.
# Migration result: Migration of url-shorten-service to k8s-worker-8 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice unique-id-service migrated successfully to k8s-worker-5.
# Migration result: Migration of unique-id-service to k8s-worker-5 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice compose-post-service migrated successfully to k8s-worker-1.
# Migration result: Migration of compose-post-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of home-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-service migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mention-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mention-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-service migrated successfully to k8s-worker-2.
# Migration result: Migration of media-service to k8s-worker-2 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice text-service migrated successfully to k8s-worker-1.
# Migration result: Migration of text-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-service migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-mongodb migrated successfully to k8s-worker-14.
# Migration result: Migration of media-mongodb to k8s-worker-14 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-service migrated successfully to k8s-worker-10.
# Migration result: Migration of user-service to k8s-worker-10 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-frontend migrated successfully to k8s-worker-12.
# Migration result: Migration of media-frontend to k8s-worker-12 completed.
# Average response time = 205.75 ms
# Trigger = True
# Ready Deployments: ['compose-post-service', 'home-timeline-redis', 'home-timeline-service', 'jaeger', 'media-frontend', 'media-memcached', 'media-mongodb', 'media-service', 'nginx-thrift', 'post-storage-memcached', 'post-storage-mongodb', 'post-storage-service', 'social-graph-mongodb', 'social-graph-redis', 'social-graph-service', 'text-service', 'unique-id-service', 'url-shorten-memcached', 'url-shorten-mongodb', 'url-shorten-service', 'user-memcached', 'user-mention-service', 'user-mongodb', 'user-service', 'user-timeline-mongodb', 'user-timeline-redis', 'user-timeline-service']
# from compose-post-service to home-timeline-service ~ 33.3 KB
# from compose-post-service to media-service ~ 47.1 KB
# from compose-post-service to post-storage-service ~ 187.3 KB
# from compose-post-service to text-service ~ 257.9 KB
# from compose-post-service to unique-id-service ~ 29.0 KB
# from compose-post-service to user-service ~ 39.6 KB
# from compose-post-service to user-timeline-service ~ 32.2 KB
# from home-timeline-service to home-timeline-redis ~ 43.2 KB
# from home-timeline-service to post-storage-service ~ 145.7 KB
# from home-timeline-service to social-graph-service ~ 22.3 KB
# from nginx-thrift to compose-post-service ~ 145.8 KB
# from nginx-thrift to home-timeline-service ~ 141.6 KB
# from nginx-thrift to user-timeline-service ~ 0.0 KB
# from post-storage-service to post-storage-memcached ~ 0.0 KB
# from post-storage-service to post-storage-mongodb ~ 0.0 KB
# from social-graph-service to social-graph-mongodb ~ 34.2 KB
# from social-graph-service to social-graph-redis ~ 7.1 KB
# from text-service to url-shorten-service ~ 0.0 KB
# from text-service to user-mention-service ~ 31.2 KB
# from url-shorten-service to url-shorten-mongodb ~ 0.0 KB
# from user-mention-service to user-memcached ~ 0.0 KB
# from user-mention-service to user-mongodb ~ 0.0 KB
# from user-service to user-mongodb ~ 1.0 KB
# from user-timeline-service to post-storage-service ~ 0.0 KB
# from user-timeline-service to user-timeline-mongodb ~ 64.7 KB
# from user-timeline-service to user-timeline-redis ~ 0.0 KB
# [Policy1CallGraphAware] Updated traffic matrix for app in namespace social-network with 17 edges.
# === Scenario1: Call-Graph_Aware ===
#  Pod compose-post-service-5577db79f5-mfprk -> schedule to Node k8s-worker-1
#  Pod text-service-7fc68b959d-5tlcn -> schedule to Node k8s-worker-1
#  Pod home-timeline-service-765d6df88f-8fqrb -> schedule to Node k8s-worker-1
#  Pod post-storage-service-665799f78d-n68dd -> schedule to Node k8s-worker-1
#  Pod user-timeline-service-69b9bf6d6f-wgpr7 -> schedule to Node k8s-worker-1
#  Pod user-timeline-mongodb-569fc84d55-z2rnw -> schedule to Node k8s-worker-1
#  Pod social-graph-service-695bd7747d-srxcl -> schedule to Node k8s-worker-1
#  Pod social-graph-mongodb-d57786c7d-rbn2c -> schedule to Node k8s-worker-1
#  Pod user-service-76c885b76-69qm7 -> schedule to Node k8s-worker-1
#  Pod user-mongodb-5b44c784c7-gph2n -> schedule to Node k8s-worker-1
#  Pod home-timeline-redis-bbf6bd4f4-sgc2d -> schedule to Node k8s-worker-10
#  Pod url-shorten-service-77845c664-rdc8h -> schedule to Node k8s-worker-10
#  Pod user-memcached-6cb4dbc8cf-ww57h -> schedule to Node k8s-worker-11
#  Pod media-frontend-b56f8bfbb-f69qm -> schedule to Node k8s-worker-12
#  Pod user-mention-service-954dbd6f6-cbqgd -> schedule to Node k8s-worker-12
#  Pod media-memcached-6b84d9f97d-gtgr5 -> schedule to Node k8s-worker-13
#  Pod user-timeline-redis-67d44cfbb9-qncqm -> schedule to Node k8s-worker-13
#  Pod media-mongodb-75b8dbfb48-zn2z8 -> schedule to Node k8s-worker-14
#  Pod media-service-5fd4dc8ffd-87r2j -> schedule to Node k8s-worker-2
#  Pod post-storage-memcached-557d6f7b5-mhdjp -> schedule to Node k8s-worker-4
#  Pod post-storage-mongodb-77f68cd446-5z47s -> schedule to Node k8s-worker-5
#  Pod social-graph-redis-56c7dd9444-jgtb7 -> schedule to Node k8s-worker-6
#  Pod unique-id-service-7b76c988d7-r4gq5 -> schedule to Node k8s-worker-7
#  Pod url-shorten-memcached-8568755b4-scg74 -> schedule to Node k8s-worker-8
#  Pod url-shorten-mongodb-bb698d8c7-nhpzq -> schedule to Node k8s-worker-9
# Starting migration of compose-post-service to k8s-worker-1
# Starting migration of text-service to k8s-worker-1
# Starting migration of home-timeline-service to k8s-worker-1
# Starting migration of post-storage-service to k8s-worker-1
# Starting migration of user-timeline-service to k8s-worker-1
# Starting migration of user-timeline-mongodb to k8s-worker-1
# Starting migration of social-graph-service to k8s-worker-1
# Starting migration of social-graph-mongodb to k8s-worker-1
# Starting migration of user-service to k8s-worker-1
# Starting migration of user-mongodb to k8s-worker-1
# Starting migration of home-timeline-redis to k8s-worker-10
# Starting migration of url-shorten-service to k8s-worker-10
# Starting migration of user-memcached to k8s-worker-11
# Starting migration of media-frontend to k8s-worker-12
# Starting migration of user-mention-service to k8s-worker-12
# Deployment 'compose-post-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-memcached to k8s-worker-13
# Starting migration of user-timeline-redis to k8s-worker-13
# Starting migration of media-mongodb to k8s-worker-14
# Deployment 'text-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of media-service to k8s-worker-2
# Deployment 'user-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of post-storage-memcached to k8s-worker-4
# Deployment 'social-graph-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of post-storage-mongodb to k8s-worker-5
# Deployment 'user-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-redis' patched to schedule pods on 'k8s-worker-10'.
# Waiting for the rolling update to complete...
# Starting migration of social-graph-redis to k8s-worker-6
# Deployment 'social-graph-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Starting migration of unique-id-service to k8s-worker-7
# Starting migration of url-shorten-memcached to k8s-worker-8
# Starting migration of url-shorten-mongodb to k8s-worker-9
# Deployment 'social-graph-redis' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'user-mention-service' patched to schedule pods on 'k8s-worker-12'.
# Waiting for the rolling update to complete...
# Deployment 'media-mongodb' patched to schedule pods on 'k8s-worker-14'.
# Waiting for the rolling update to complete...
# Deployment 'unique-id-service' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-mongodb' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-memcached' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-service' patched to schedule pods on 'k8s-worker-10'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-mongodb' patched to schedule pods on 'k8s-worker-9'.
# Waiting for the rolling update to complete...
# Deployment 'user-memcached' patched to schedule pods on 'k8s-worker-11'.
# Waiting for the rolling update to complete...
# Deployment 'media-service' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-redis' patched to schedule pods on 'k8s-worker-13'.
# Waiting for the rolling update to complete...
# Deployment 'media-memcached' patched to schedule pods on 'k8s-worker-13'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-memcached' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# Deployment 'media-frontend' patched to schedule pods on 'k8s-worker-12'.
# Waiting for the rolling update to complete...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice compose-post-service migrated successfully to k8s-worker-1.
# Migration result: Migration of compose-post-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-service migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-service migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-redis migrated successfully to k8s-worker-10.
# Migration result: Migration of home-timeline-redis to k8s-worker-10 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice text-service migrated successfully to k8s-worker-1.
# Migration result: Migration of text-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of home-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-mongodb migrated successfully to k8s-worker-14.
# Migration result: Migration of media-mongodb to k8s-worker-14 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-memcached migrated successfully to k8s-worker-13.
# Migration result: Migration of media-memcached to k8s-worker-13 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-service migrated successfully to k8s-worker-2.
# Migration result: Migration of media-service to k8s-worker-2 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-frontend migrated successfully to k8s-worker-12.
# Migration result: Migration of media-frontend to k8s-worker-12 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-mongodb migrated successfully to k8s-worker-9.
# Migration result: Migration of url-shorten-mongodb to k8s-worker-9 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-memcached migrated successfully to k8s-worker-8.
# Migration result: Migration of url-shorten-memcached to k8s-worker-8 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-redis migrated successfully to k8s-worker-13.
# Migration result: Migration of user-timeline-redis to k8s-worker-13 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-memcached migrated successfully to k8s-worker-4.
# Migration result: Migration of post-storage-memcached to k8s-worker-4 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-memcached migrated successfully to k8s-worker-11.
# Migration result: Migration of user-memcached to k8s-worker-11 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-mongodb migrated successfully to k8s-worker-5.
# Migration result: Migration of post-storage-mongodb to k8s-worker-5 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-redis migrated successfully to k8s-worker-6.
# Migration result: Migration of social-graph-redis to k8s-worker-6 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice unique-id-service migrated successfully to k8s-worker-7.
# Migration result: Migration of unique-id-service to k8s-worker-7 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-service migrated successfully to k8s-worker-10.
# Migration result: Migration of url-shorten-service to k8s-worker-10 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mention-service migrated successfully to k8s-worker-12.
# Migration result: Migration of user-mention-service to k8s-worker-12 completed.
# Average response time = 135.23 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 130.51 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 130.59 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 127.96 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 126.47 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 127.44 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 126.34 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 126.23 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 126.63 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 126.06 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 125.79 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 126.15 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 123.99 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 113.42 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 110.69 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 92.80 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 74.90 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 68.82 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 64.65 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 64.28 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 66.43 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 63.51 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 60.62 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 61.96 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 59.72 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 59.57 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 60.30 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 58.56 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 58.42 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 58.92 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.89 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.30 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.82 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.47 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.55 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 55.56 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.41 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.04 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 55.08 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.65 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.75 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 55.08 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 55.31 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 55.31 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 54.64 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.22 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 58.23 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.81 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 53.24 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 52.56 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 53.75 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 52.55 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 52.17 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 52.39 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 51.44 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 52.12 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 51.99 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 51.63 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 52.00 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 52.01 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 53.56 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 53.56 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 52.17 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.12 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 82.42 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 28
#      23         time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds
#      25 # wait 60*16*2 seconds till the default k8s policy evaluation first, and then Policy1
#      26 # 60*3 seconds is the sleep time two evaluations (default k8s policy first, and then Policy1)
#      27 # time.sleep(60*16*2 + 60*3)
# ---> 28 evaluate_policy1_scheudlder()
#      30 # (1) before running the Policy1 scheduler, we run the workload for the first time
#      31 # to obtain performance in default k8s scheduler
#      32
#    (...)
#      44 # workload_thread.join()
#      45 # scheduler_thread.join()
#
# Cell In[4], line 23, in evaluate_policy1_scheudlder()
#      21 while True:
#      22     policy1.run()
# ---> 23     time.sleep(20)
#
# KeyboardInterrupt:

# %%
app1_prom_url = "http://10.105.116.175:9090"
app1_qos_target = 150  # QoS target in milliseconds
# time_window is the look_back window for the average response time
app1_time_window = 1  # Time window in minutes,
app1_namespace = 'social-network'
app1_response_code = '200'  # HTTP response code to consider

# Create an instance of the scheduler
policy1 = Policy1CallGraphAware()
policy1.initialize_policy(dynamics_config={"traffic_pairs": {}}, prom_url=app1_prom_url, 
                        qos_target = app1_qos_target, time_window = app1_time_window, 
                        namespace = app1_namespace, response_code = app1_response_code)

# Run the scheduler
while True:
    policy1.run()
    time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds

# %%
# 1) Gather cluster data
raw_nodes = gather_all_nodes()
candidate_nodes = build_nodeinfo_objects(raw_nodes)

# Gather pod data for each policy
# Deploye three instances of social-network application in different namespaces
# each policy will be applied to each namespace
raw_pods_Policy1 = gather_all_pods(namespace="social-network")
pods_Policy1 = build_podinfo_objects(raw_pods_Policy1)

raw_pods_Policy2 = gather_all_pods(namespace="social-network2")
pods_Policy2 = build_podinfo_objects(raw_pods_Policy2)

raw_pods_Policy3 = gather_all_pods(namespace="social-network3")
pods_Policy3 = build_podinfo_objects(raw_pods_Policy3)

# 2) (Optional) Build a call graph from 'graph_builder.py'
#    This might be used by Policy1 to place heavily communicating microservices.
G = build_call_graph(namespace="social-network")
# Convert the NetworkX graph to a simple dict: (src, dst) -> traffic_kb
traffic_matrix = {}
for (u, v, data) in G.edges(data=True):
    traffic_matrix[(u, v)] = data.get("weight", 0.0)  # store as KB

# 3) Initialize each policy with scenario-specific config
policy1 = Policy1CallGraphAware()
policy1.initialize_policy(dynamics_config={"traffic_matrix": traffic_matrix})

policy2 = Policy2LatencyAware()
policy2.initialize_policy(dynamics_config={"latency_threshold": 5.0})  # example

policy3 = Policy3BandwidthAware()
policy3.initialize_policy(dynamics_config={"high_traffic_threshold": 300.0})  # example

# 4) Choose which scenario you want to test
# Scenario 1: call-graph dynamics => we expect policy1 to shine
print("=== Scenario1: Call-Graph_Aware ===")
decisions_s1 = policy1.schedule_all(pods_Policy1, candidate_nodes)
for dec in decisions_s1:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")

# Scenario 2: cross-node delays => policy2 might do better
print("\n=== Scenario2: Latency_Aware ===")
decisions_s2 = policy2.schedule_all(pods_Policy2, candidate_nodes)
for dec in decisions_s2:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")

# Scenario 3: cross-node bandwidth changes => policy3 might do better
print("\n=== Scenario3: Bandwidth_Aware ===")
decisions_s3 = policy3.schedule_all(pods_Policy3, candidate_nodes)
for dec in decisions_s3:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")
