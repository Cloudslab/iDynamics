# %%
# from Policy1_demo_workloads import wrk_different_requests
# from iDynamicsPackagesModules.SchedulingPolicyExtender.my_cluster_utils import (
#     gather_all_nodes, build_nodeinfo_objects,
#     build_podinfo_objects, gather_all_pods)

# from iDynamicsPackagesModules.GraphDynamicsAnalyzer.graph_builder import build_call_graph
from iDynamicsPackagesModules.Evaluations.Cluster_5_Nodes.Policy1_eval_Graph_dynamics.Policy1_Call_Graph_Aware import Policy1CallGraphAware
# from iDynamicsPackagesModules.Evaluations.Policy2_eval_Delay_dynamics.Policy2_Latency_Aware import Policy2LatencyAware
# from iDynamicsPackagesModules.Evaluations.Policy3_eval_Bandwidth_dynamics.Policy3_Bandwidth_Aware import Policy3BandwidthAware

# from Policy1_demo_workloads import run_workload_varing_callGraph

# %%
import time
import threading


def evaluate_policy1_scheudlder():
    # Initialize the scheduler with necessary parameters
    app1_prom_url = "http://10.105.116.175:9090"
    app1_qos_target = 100 #150  # QoS target in milliseconds
    # time_window is the look_back window for the average response time
    app1_time_window = 1  # Time window in minutes,
    app1_namespace = 'social-network'
    app1_response_code = '200'  # HTTP response code to consider

    # Create an instance of the scheduler
    policy1 = Policy1CallGraphAware()
    policy1.initialize_policy(dynamics_config={"traffic_pairs": {}}, prom_url=app1_prom_url, 
                            qos_target = app1_qos_target, time_window = app1_time_window, 
                            namespace = app1_namespace, response_code = app1_response_code)

    # Run the scheduler
    while True:
        policy1.run()
        time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds

# time.sleep(60*16*2 + 60*3)
evaluate_policy1_scheudlder()

# (1) before running the Policy1 scheduler, we run the workload for the first time 
# to obtain performance in default k8s scheduler

# run_workload_varing_callGraph(each_wrk2_duration='3m') # eg., "30s", "1m", 5m", "10m", "15m"
#sleep for 2 mins
# time.sleep(180)

# (2) Conccurently run evaluate_policy1_scheudlder() and run_workload_varing_callGraph()
# workload_thread = threading.Thread(target = run_workload_varing_callGraph, kwargs={'each_wrk2_duration':'3m'})
# scheduler_thread = threading.Thread(target=evaluate_policy1_scheudlder)
# workload_thread.start()
# scheduler_thread.start()

# # Wait for both threads to finish
# workload_thread.join()
# scheduler_thread.join()
# Out:
# Average response time = 58.96 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.58 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 58.95 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.99 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.88 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.32 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 56.61 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.05 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.42 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.73 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 58.87 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 57.88 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 59.04 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 66.55 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Total requests sum is zero, cannot compute average response time.
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.34 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.32 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.52 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.48 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.52 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.63 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.89 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.15 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.93 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.26 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.94 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 34.45 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.98 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.01 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.35 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.83 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.94 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 33.17 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.96 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.81 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.95 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.91 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.82 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 32.85 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 39.18 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 68.90 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 76.78 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 88.50 ms
# Trigger = False
# [Policy1CallGraphAware] No migration triggered.
# Average response time = 157.81 ms
# Trigger = True
# Ready Deployments: ['compose-post-service', 'home-timeline-redis', 'home-timeline-service', 'jaeger', 'media-frontend', 'media-memcached', 'media-mongodb', 'media-service', 'nginx-thrift', 'post-storage-memcached', 'post-storage-mongodb', 'post-storage-service', 'social-graph-mongodb', 'social-graph-redis', 'social-graph-service', 'text-service', 'unique-id-service', 'url-shorten-memcached', 'url-shorten-mongodb', 'url-shorten-service', 'user-memcached', 'user-mention-service', 'user-mongodb', 'user-service', 'user-timeline-mongodb', 'user-timeline-redis', 'user-timeline-service']
# from compose-post-service to home-timeline-service ~ 23.0 KB
# from compose-post-service to media-service ~ 32.2 KB
# from compose-post-service to post-storage-service ~ 124.9 KB
# from compose-post-service to text-service ~ 172.9 KB
# from compose-post-service to unique-id-service ~ 19.4 KB
# from compose-post-service to user-service ~ 26.9 KB
# from compose-post-service to user-timeline-service ~ 21.6 KB
# from home-timeline-service to home-timeline-redis ~ 39.6 KB
# from home-timeline-service to post-storage-service ~ 133.1 KB
# from home-timeline-service to social-graph-service ~ 19.3 KB
# from nginx-thrift to compose-post-service ~ 98.5 KB
# from nginx-thrift to home-timeline-service ~ 158.7 KB
# from nginx-thrift to user-timeline-service ~ 0.0 KB
# from post-storage-service to post-storage-memcached ~ 0.0 KB
# from post-storage-service to post-storage-mongodb ~ 167.1 KB
# from social-graph-service to social-graph-mongodb ~ 33.4 KB
# from social-graph-service to social-graph-redis ~ 7.0 KB
# from text-service to url-shorten-service ~ 103.7 KB
# from text-service to user-mention-service ~ 29.3 KB
# from url-shorten-service to url-shorten-mongodb ~ 93.4 KB
# from user-mention-service to user-memcached ~ 32.3 KB
# from user-mention-service to user-mongodb ~ 38.7 KB
# from user-service to user-mongodb ~ 1.0 KB
# from user-timeline-service to post-storage-service ~ 0.0 KB
# from user-timeline-service to user-timeline-mongodb ~ 221.1 KB
# from user-timeline-service to user-timeline-redis ~ 12.4 KB
# [Policy1CallGraphAware] Updated traffic matrix for app in namespace social-network with 23 edges.
# === Scenario1: Call-Graph_Aware ===
#  Pod user-timeline-service-6c7b9c48bc-g9bgv -> schedule to Node k8s-worker-1
#  Pod user-timeline-mongodb-865c9c4975-rxfkj -> schedule to Node k8s-worker-1
#  Pod compose-post-service-79fffc8f65-fttt7 -> schedule to Node k8s-worker-1
#  Pod text-service-84d48878-l2zqj -> schedule to Node k8s-worker-1
#  Pod post-storage-service-696b99f894-sqbvs -> schedule to Node k8s-worker-1
#  Pod post-storage-mongodb-6cd66b64db-pzrwd -> schedule to Node k8s-worker-1
#  Pod home-timeline-service-5847cc645f-5gqx8 -> schedule to Node k8s-worker-1
#  Pod url-shorten-service-8487489949-htszc -> schedule to Node k8s-worker-1
#  Pod url-shorten-mongodb-5d6779b787-2927h -> schedule to Node k8s-worker-1
#  Pod user-mention-service-6f9554bdfd-5h7p6 -> schedule to Node k8s-worker-1
#  Pod user-mongodb-54f7856897-c29dc -> schedule to Node k8s-worker-1
#  Pod social-graph-service-7f767545d4-wvl2g -> schedule to Node k8s-worker-1
#  Pod social-graph-mongodb-7db6d5b58-fnszm -> schedule to Node k8s-worker-1
#  Pod home-timeline-redis-74777776d8-4v7j9 -> schedule to Node k8s-worker-10
#  Pod media-frontend-6f8b6db9bb-jktmp -> schedule to Node k8s-worker-12
#  Pod media-memcached-5584c4bbdf-hwbdf -> schedule to Node k8s-worker-13
#  Pod media-mongodb-6fd7768d66-k9s9k -> schedule to Node k8s-worker-14
#  Pod media-service-7fbfc5f4c-tkdpd -> schedule to Node k8s-worker-2
#  Pod post-storage-memcached-786b6455f-mq4sb -> schedule to Node k8s-worker-3
#  Pod social-graph-redis-6b4dcf589-ltsvf -> schedule to Node k8s-worker-4
#  Pod unique-id-service-78db644977-9bq58 -> schedule to Node k8s-worker-5
#  Pod url-shorten-memcached-645954f675-jqjk9 -> schedule to Node k8s-worker-6
#  Pod user-memcached-8474bbc969-pbnwm -> schedule to Node k8s-worker-7
#  Pod user-service-64b5d876b-7sqgv -> schedule to Node k8s-worker-8
#  Pod user-timeline-redis-75647777b4-9dmxb -> schedule to Node k8s-worker-9
# Starting migration of user-timeline-service to k8s-worker-1
# Starting migration of user-timeline-mongodb to k8s-worker-1
# Starting migration of compose-post-service to k8s-worker-1
# Starting migration of text-service to k8s-worker-1
# Starting migration of post-storage-service to k8s-worker-1
# Starting migration of post-storage-mongodb to k8s-worker-1
# Starting migration of home-timeline-service to k8s-worker-1
# Starting migration of url-shorten-service to k8s-worker-1
# Starting migration of url-shorten-mongodb to k8s-worker-1
# Starting migration of user-mention-service to k8s-worker-1
# Starting migration of user-mongodb to k8s-worker-1
# Starting migration of social-graph-service to k8s-worker-1
# Starting migration of social-graph-mongodb to k8s-worker-1
# Starting migration of home-timeline-redis to k8s-worker-10
# Starting migration of media-frontend to k8s-worker-12
# Starting migration of media-memcached to k8s-worker-13
# Starting migration of media-mongodb to k8s-worker-14
# Starting migration of media-service to k8s-worker-2
# Starting migration of post-storage-memcached to k8s-worker-3
# Starting migration of social-graph-redis to k8s-worker-4
# Starting migration of unique-id-service to k8s-worker-5
# Starting migration of url-shorten-memcached to k8s-worker-6
# Starting migration of user-memcached to k8s-worker-7
# Starting migration of user-service to k8s-worker-8
# Starting migration of user-timeline-redis to k8s-worker-9
# Deployment 'user-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'compose-post-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-redis' patched to schedule pods on 'k8s-worker-9'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-redis' patched to schedule pods on 'k8s-worker-10'.
# Waiting for the rolling update to complete...
# Deployment 'user-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-memcached' patched to schedule pods on 'k8s-worker-6'.
# Waiting for the rolling update to complete...
# Deployment 'unique-id-service' patched to schedule pods on 'k8s-worker-5'.
# Waiting for the rolling update to complete...
# Deployment 'user-mention-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-memcached' patched to schedule pods on 'k8s-worker-7'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'url-shorten-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'media-mongodb' patched to schedule pods on 'k8s-worker-14'.
# Waiting for the rolling update to complete...
# Deployment 'media-memcached' patched to schedule pods on 'k8s-worker-13'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-memcached' patched to schedule pods on 'k8s-worker-3'.
# Waiting for the rolling update to complete...
# Deployment 'user-timeline-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'text-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-redis' patched to schedule pods on 'k8s-worker-4'.
# Waiting for the rolling update to complete...
# Deployment 'post-storage-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'social-graph-mongodb' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'home-timeline-service' patched to schedule pods on 'k8s-worker-1'.
# Waiting for the rolling update to complete...
# Deployment 'user-service' patched to schedule pods on 'k8s-worker-8'.
# Waiting for the rolling update to complete...
# Deployment 'media-service' patched to schedule pods on 'k8s-worker-2'.
# Waiting for the rolling update to complete...
# Deployment 'media-frontend' patched to schedule pods on 'k8s-worker-12'.
# Waiting for the rolling update to complete...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-service migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice compose-post-service migrated successfully to k8s-worker-1.
# Migration result: Migration of compose-post-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-service migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-memcached migrated successfully to k8s-worker-3.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# Migration result: Migration of post-storage-memcached to k8s-worker-3 completed.
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 1
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated=all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
#  False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-redis migrated successfully to k8s-worker-4.
# Migration result: Migration of social-graph-redis to k8s-worker-4 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated=all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
#  False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice post-storage-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of post-storage-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice social-graph-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of social-graph-mongodb to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of url-shorten-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mongodb migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mongodb to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice unique-id-service migrated successfully to k8s-worker-5.
# Migration result: Migration of unique-id-service to k8s-worker-5 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice media-service migrated successfully to k8s-worker-2.
# Migration result: Migration of media-service to k8s-worker-2 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-timeline-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice text-service migrated successfully to k8s-worker-1.
# Migration result: Migration of text-service to k8s-worker-1 completed.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice url-shorten-service migrated successfully to k8s-worker-1.
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice home-timeline-service migrated successfully to k8s-worker-1.
# Migration result: Migration of url-shorten-service to k8s-worker-1 completed.
# Migration result: Migration of home-timeline-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= True
# len(pods)= 1
# All pods are running on the new node.
# Microservice user-mention-service migrated successfully to k8s-worker-1.
# Migration result: Migration of user-mention-service to k8s-worker-1 completed.
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# ...
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...
# all_pods_updated= False
# len(pods)= 2
# Rolling update in progress...

# %%
app1_prom_url = "http://10.105.116.175:9090"
app1_qos_target = 150  # QoS target in milliseconds
# time_window is the look_back window for the average response time
app1_time_window = 1  # Time window in minutes,
app1_namespace = 'social-network'
app1_response_code = '200'  # HTTP response code to consider

# Create an instance of the scheduler
policy1 = Policy1CallGraphAware()
policy1.initialize_policy(dynamics_config={"traffic_pairs": {}}, prom_url=app1_prom_url, 
                        qos_target = app1_qos_target, time_window = app1_time_window, 
                        namespace = app1_namespace, response_code = app1_response_code)

# Run the scheduler
while True:
    policy1.run()
    time.sleep(20) # Run the scheduler to regularly  check if the QoS if violated every 30 seconds

# %%
# 1) Gather cluster data
raw_nodes = gather_all_nodes()
candidate_nodes = build_nodeinfo_objects(raw_nodes)

# Gather pod data for each policy
# Deploye three instances of social-network application in different namespaces
# each policy will be applied to each namespace
raw_pods_Policy1 = gather_all_pods(namespace="social-network")
pods_Policy1 = build_podinfo_objects(raw_pods_Policy1)

raw_pods_Policy2 = gather_all_pods(namespace="social-network2")
pods_Policy2 = build_podinfo_objects(raw_pods_Policy2)

raw_pods_Policy3 = gather_all_pods(namespace="social-network3")
pods_Policy3 = build_podinfo_objects(raw_pods_Policy3)

# 2) (Optional) Build a call graph from 'graph_builder.py'
#    This might be used by Policy1 to place heavily communicating microservices.
G = build_call_graph(namespace="social-network")
# Convert the NetworkX graph to a simple dict: (src, dst) -> traffic_kb
traffic_matrix = {}
for (u, v, data) in G.edges(data=True):
    traffic_matrix[(u, v)] = data.get("weight", 0.0)  # store as KB

# 3) Initialize each policy with scenario-specific config
policy1 = Policy1CallGraphAware()
policy1.initialize_policy(dynamics_config={"traffic_matrix": traffic_matrix})

policy2 = Policy2LatencyAware()
policy2.initialize_policy(dynamics_config={"latency_threshold": 5.0})  # example

policy3 = Policy3BandwidthAware()
policy3.initialize_policy(dynamics_config={"high_traffic_threshold": 300.0})  # example

# 4) Choose which scenario you want to test
# Scenario 1: call-graph dynamics => we expect policy1 to shine
print("=== Scenario1: Call-Graph_Aware ===")
decisions_s1 = policy1.schedule_all(pods_Policy1, candidate_nodes)
for dec in decisions_s1:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")

# Scenario 2: cross-node delays => policy2 might do better
print("\n=== Scenario2: Latency_Aware ===")
decisions_s2 = policy2.schedule_all(pods_Policy2, candidate_nodes)
for dec in decisions_s2:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")

# Scenario 3: cross-node bandwidth changes => policy3 might do better
print("\n=== Scenario3: Bandwidth_Aware ===")
decisions_s3 = policy3.schedule_all(pods_Policy3, candidate_nodes)
for dec in decisions_s3:
    print(f"  Pod {dec.pod_name} -> Node {dec.selected_node}")
